# %%
# !pip install arxiv

# %%
import arxiv

# Construct the default API client.
client = arxiv.Client()

# Search for the 10 most recent articles matching the keyword "quantum."
search = arxiv.Search(
  query = "Gilbert damping constant",
  max_results = 2000,
  sort_by = arxiv.SortCriterion.SubmittedDate
)

results = client.results(search)

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(columns=['url','title','id'])
for i, result in enumerate(search.results()):
    id = result.entry_id.split('/')[-1]
    df.loc[i] = [result.entry_id,result.title,id]

# %%
df.to_csv('paper.csv')

# %%
import time
import random

# %%
import os
os.system('mkdir paper')
# %cd paper

# %%
for i in range(df.shape[0]):
    download_id = df.loc[i]['id']
    paper = next(arxiv.Client().results(arxiv.Search(id_list=[download_id])))
    # Download the PDF to the PWD with a default filename.
    print(download_id)
    paper.download_pdf()
    time.sleep(random.random()+2)
