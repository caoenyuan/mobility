# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments
from datasets import load_dataset, Dataset, concatenate_datasets
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training
from trl import SFTTrainer

import requests
from PIL import Image
from transformers import MllamaForConditionalGeneration, AutoProcessor

# %%
model_name = "meta-llama/Llama-3.2-11B-Vision-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name)
#model = AutoModelForCausalLM.from_pretrained(model_name,
model = MllamaForConditionalGeneration.from_pretrained(model_name,
                                             #load_in_8bit=True,
                                             torch_dtype=torch.bfloat16,
                                             device_map="auto"
                                            )
#processor = AutoProcessor.from_pretrained(model_name)
# Out:
# The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
import pandas as pd
import os

# 指定user文件夹路径
user_folder = "users_cleaned"  

# 创建一个字典存储所有df
dfs = {}

# 遍历user文件夹下的文件
for i, filename in enumerate(os.listdir(user_folder)):
    if filename.endswith(".csv"):
        # 读取每个csv文件
        filepath = os.path.join(user_folder, filename)
        dfs[i+1] = pd.read_csv(filepath)
        print(i+1)
        print(filename)
        #print(dfs[i+1].head())  # 打印前5行以确认读取成功
else:
    if not dfs:  # 判断dfs字典是否为空
        print("未在user文件夹中找到csv文件。")

# %%
for key in dfs:
  dfs[key] = dfs[key][dfs[key]['coordinate'] != '0,0']

# %%
for i in dfs:
    dfs[i] = dfs[i][~dfs[i]['content'].str.contains('转发')]

# %%
with open('prompt.txt', 'r') as file:
    prompt = file.read()

# %%
with open('prompt_poi.txt', 'r') as file:
    prompt = file.read()

# %%
with open('prompt_img.txt', 'r') as file:
    prompt = file.read()

# %%
def generate_prompt(content):
    begin = "<|begin_of_text|><|start_header_id|>system<|end_header_id|>\n"
    #syst = "<<SYS>> You are a helpful assistant, always answer as helpfully as possible.\n If a question does not make any sense, or is not factually coherent, explain why instead of answering something not correct. If you don't know the answer to a question, please don't share false information.<</SYS>>\n"
    #inst = "Read the following text. Does it mention the Gilbert damping constant of a certain material? If so, list the corresponding material and its Gilbert damping canstant.\n" + content
    syst = "You are a helpful AI assistant, answer the question as short as possible.\n<|eot_id|><|start_header_id|>user<|end_header_id|>\n"
    #inst = "What is the attitude of the following text towards electric vehicles or autonomous driving? Answer with positive, negative or neutral. Also classify it as one of the following categories:\n1: Safety\n2: Price and Cost\n3: Technology maturity and infrastructure\n4: User Experience\n5: Policy and market\n6: Ethical and social impact\n7: Other or cannot be classified\nOnly answer the attitude and the category number, and do not answer anything else.\nText: "+content
    end = "\n<|eot_id|><|start_header_id|>assistant<|end_header_id|>\n"
    prompt = (" ").join([begin, syst, content, end])
    return prompt

print(generate_prompt('Hello'))
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#  You are a helpful AI assistant, answer the question as short as possible.
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#  Hello
# <|eot_id|><|start_header_id|>assistant<|end_header_id|>

# %%
output_string = ""

for index, row in dfs[10].iloc[0:30].iterrows():
    output_string += f"{row['publish_time']}, {row['location']} ({row['coordinate']}), {row['content']}\n"
    img_url = row['img_urls']
    #output_str = f"{row['publish_time']}, {row['location']} ({row['coordinate']}), {row['content']}"
    #print(output_str)
#print(output_string)

#download_image(img_url, save_path)
new_text = prompt + '\n\nContents: \n' + output_string
#print(new_text)
print(generate_prompt(new_text))
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#  You are a helpful AI assistant, answer the question as short as possible.
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# Home: (位置) (longitude1, latitude1).
# Works/studies at  (位置) (longitude2, latitude2).
# Work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace.
# Do not answer anything else.
#
# Contents:
# 2012-08-22 09:14:00, 网页链接 (116.595832,39.913074), 小区里的流浪咪，ms以前没见过…警惕性很高,离着那么远拍照都跑开了… 我在:网页链接  显示地图 原图
# 2012-08-21 11:20:00, 网页链接 (116.594215,39.913085), 晴好天…洗衣日 我在:网页链接  显示地图
# 2012-09-02 15:02:00, 网页链接 (116.407325,39.915454), 看演出前逛了两小时街…真累…坐下就困…[睡觉] 我在:网页链接  显示地图
# 2012-09-24 09:49:00, 管庄路 (116.590652,39.923809), 邮局拿号…前面居然有70个人在等候~ 我在:管庄路  显示地图
# 2012-09-30 09:37:00, 网页链接 (116.647033,39.776382), 京津还算通畅… 我在:网页链接  显示地图
# 2012-09-30 09:00:00, 网页链接 (116.688926,39.924228), 上高速喽… 我在:网页链接  显示地图
# 2012-10-01 20:48:00, 朝阳路辅路 (116.595779,39.91312), 斯蒂芬金的故事贩卖机…第一个故事就吓到我了，不适合天黑后读的故事，尤其对于越年长越胆小的人… 我在:朝阳路辅路  显示地图
# 2012-09-30 15:16:00, 网页链接 (117.028686,38.796283), 河北出事故…堵到天津界…我们返航了~身随心动…爷换地方过节去… 我在:网页链接  显示地图
# 2012-10-03 12:49:00, 网页链接 (116.513618,40.95058), 分享图片 我在:网页链接  显示地图 原图
# 2012-10-05 21:41:00, 朝阳路辅路 (116.595787,39.914188), 给小朋友们准备的明天午餐，第一次用模具做饭团，偷懒随便撕了点海苔放上，败笔啊!一很丑有木有?我会告诉你是小汽车和小鱼造型的饭团么?会么?会么? 我在:朝阳路辅路  显示地图 原图
# 2012-12-17 11:52:00, 朝阳路辅路 (116.59671,39.911949), 某人的新宠送到了@海风吹拂2011 我在:朝阳路辅路  显示地图 原图
# 2012-12-14 07:19:00, 朝阳路辅路 (116.595787,39.914188), 天地雪白，叫小子起床一声"下雪了"…小子立即从梦中蹦起来…心情大好，[雪][雪][雪][雪][雪] 我在:朝阳路辅路  显示地图
# 2013-01-12 18:29:00, 双桥东路环岛 (116.598289,39.915252), 新宠到手，各大品牌大板板手机太多了，看晕了!旧手机早就坚持不住罢工咯。 我在:双桥东路环岛  显示地图 原图
# 2013-01-18 08:01:00, 双桥东路环岛 (116.597106,39.915138), 口感细腻的年轮蛋糕，没得早餐吃的娘俩一起开动了。 我在:双桥东路环岛  显示地图 原图
# 2013-01-16 16:18:00, 建国路 (116.602203,39.909343), 网传很火的＂肥猫烤鱼＂，真有姑娘站门前大喝三声＂我爱吃肥猫＂的口号，店家送了一盘午餐肉 我在:建国路  显示地图 原图
# 2013-01-20 09:01:00, 朝阳北路 (116.546173,39.922744), 好基友，一辈子 我在:朝阳北路  显示地图 原图
# 2013-01-20 08:44:00, 朝阳路 (116.600883,39.912807), 出发喽[雪][雪][雪] 我在:朝阳路  显示地图 原图
# 2013-01-19 11:48:00, 朝阳路辅路 (116.57135,39.915325), 想出门逛逛，还没出小区就遭遇大堵车 我在:朝阳路辅路  显示地图
# 2013-01-25 14:36:00, 北京市朝阳区 (116.596847,39.919044), 快乐周五 我在:北京市朝阳区  显示地图 原图
# 2013-01-22 20:15:00, 朝阳路辅路 (116.596977,39.914772), 少爷自由自在的一天！原本傍晚要上课，爸爸却下午提前回家了，于是课也不去上，改成逛街吃饭电影 我在:朝阳路辅路  显示地图 原图
# 2013-01-28 11:40:00, 通惠河南路 (116.585586,39.908149), 分享图片 我在:通惠河南路  显示地图 原图
# 2013-01-26 18:56:00, 康各庄路 (116.557151,39.95438), 第二次参加定向赛，成绩很不错，小子拿了＂大奖＂，吃完午饭又去滑冰，直到回家路上才在车里睡着了。这一天，运动量超大！ 我在:康各庄路  显示地图 原图
# 2013-01-28 17:05:00, 朝阳北路 (116.595191,39.923465), 画的咋样不说，动作很有大师范儿吧！ 我在:朝阳北路  显示地图 原图
# 2013-02-01 16:55:00, 朝阳北路 (116.598449,39.924854),  我在:朝阳北路  显示地图 原图
# 2013-02-02 14:39:00, 管庄路 (116.590927,39.932266), 蓝天清风 我在:管庄路  显示地图 原图
# 2013-02-12 16:27:00, 泰安服务区 (117.005294,36.202381), 泰安，返程的第一个休息站。 我在:泰安服务区  显示地图 原图
# 2013-02-23 17:16:00, 朝阳路辅路 (116.59365,39.913307), 晒单豆荚农庄的配菜／柴蛋／黑花生，尤其艳丽的香蕉西葫芦，期待糊塌子的味道@豆荚农庄 我在:朝阳路辅路  显示地图 原图
# 2013-02-28 12:10:00, 朝阳路 (116.601821,39.913311), 风沙漫天，我这吨位都要被吹跑了，苗条妹子们，你们出门可长点小心！～抱块石头吧！ 我在:朝阳路  显示地图
# 2013-02-28 11:05:00, 朝阳路 (116.602294,39.912734), 雾霾天，口罩人。 我在:朝阳路  显示地图 原图
# 2013-03-02 20:01:00, 金盏路 (116.571533,40.002922), 夜场温泉，人少灯昏暗，水幕电影也雾蒙蒙 我在:金盏路  显示地图 原图
#
# <|eot_id|><|start_header_id|>assistant<|end_header_id|>

# %%
input_prompt = generate_prompt(new_text)
#input_tokens = tokenizer(input_prompt, return_tensors="pt")["input_ids"].to("cuda")
#inputs = tokenizer(input_prompt, return_tensors="pt", padding=True, truncation=True).to("cuda")
inputs = tokenizer(input_prompt, return_tensors="pt", truncation=True).to("cuda")
input_tokens = inputs["input_ids"]
attention_mask = inputs["attention_mask"]
with torch.cuda.amp.autocast():
    generation_output = model.generate(
        input_ids=input_tokens,
        attention_mask=attention_mask,
        max_new_tokens=256,
        do_sample=False,
        repetition_penalty=1.1,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id
    )
op = tokenizer.decode(generation_output[0], skip_special_tokens=True)
print(op)

# %%
import pandas as pd
import time

output_dir = "output"  # 指定输出目录

data = []
save_interval = 200

start_time = time.time()  # 记录开始时间

for i in range(1,len(dfs)):
    if i % 1 == 0:
        output_string = ""

        for index, row in dfs[i].iloc[0:30].iterrows():
            output_string += f"{row['publish_time']}, {row['location']} ({row['coordinate']}), {row['content']}\n"
            img_url = row['img_urls']
            #output_str = f"{row['publish_time']}, {row['location']} ({row['coordinate']}), {row['content']}"
            #print(output_str)
        #print(output_string)
        
        #download_image(img_url, save_path)
        new_text = prompt + '\n\nContents: \n' + output_string
        #print(new_text)
        #print(generate_prompt(new_text))
        
        input_prompt = generate_prompt(new_text)
        #input_tokens = tokenizer(input_prompt, return_tensors="pt")["input_ids"].to("cuda")
        #inputs = tokenizer(input_prompt, return_tensors="pt", padding=True, truncation=True).to("cuda")
        inputs = tokenizer(input_prompt, return_tensors="pt", truncation=True).to("cuda")
        input_tokens = inputs["input_ids"]
        attention_mask = inputs["attention_mask"]
        with torch.cuda.amp.autocast():
            generation_output = model.generate(
                input_ids=input_tokens,
                attention_mask=attention_mask,
                max_new_tokens=128,
                do_sample=False,
                repetition_penalty=1.1,
                num_return_sequences=1,
                eos_token_id=tokenizer.eos_token_id,
                pad_token_id=tokenizer.eos_token_id
            )
        op = tokenizer.decode(generation_output[0], skip_special_tokens=True)
        print(op)

        output_filename = os.path.join(output_dir, f"output_{i}.txt")
        # 创建空文件（如果文件不存在）
        with open(output_filename, "a+", encoding="utf-8") as f:
            pass  # 不需要写入任何内容，只是创建文件
        with open(output_filename, "w", encoding="utf-8") as f:
            f.write(op)
        '''
        inst_index = op.find('assistant\n')
        
        if inst_index != -1:
            #print(text)
            #print(op[inst_index + len('assistant\n'):])
            data.append({"number": i, "text": text, "sentiment": op[inst_index + len('assistant\n'):]})
        else:
            #print("未找到'assistant\n'标记")
            data.append({"number": i, "text": text, "sentiment":""})

        # 每 save_interval 个迭代保存一次
        if i % save_interval == 0:
            df = pd.DataFrame(data)
            df.to_csv("output_ev.csv", encoding = 'utf-8-sig', index=False, mode='a', header=False)  # 追加模式
            data = []
            end_time = time.time()  # 记录结束时间
            elapsed_time = end_time - start_time  # 计算用时
            print(f"已保存到 output_ev.csv，当前迭代次数：{i}，用时：{elapsed_time:.2f} 秒")
    
            start_time = end_time  # 更新开始时间，用于计算下一个周期的用时
        '''
# 最后一次保存
#df = pd.DataFrame(data)
#df.to_csv("output_ev.csv", encoding = 'utf-8-sig', index=False, mode='a', header=False)
#print("已保存到 output_ev.csv")
# Out:
# system
#  You are a helpful AI assistant, answer the question as short as possible.
# user
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# The user likely lives in 位置, (longitude1, latitude1).
# The user likely works/studies at 位置, (longitude2, latitude2).
# The user's work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace. Number of workplace should not be more than 2.
# Do not answer anything else.
#
# Contents:
# 2013-11-11 23:51:00, 民族大道 (114.396344,30.477156), 双11都是他们的，，，，，我都不知道买什么。 我在:民族大道  显示地图
# 2013-11-07 13:56:00, 软件园中路 (114.40347,30.481615), 现在上班的感觉就是时间过得挺快，学得挺慢，，， 我在:软件园中路  显示地图
# 2013-11-05 23:42:00, 民族大道 (114.397436,30.477216), 脚踏实地，，， 我在:民族大道  显示地图
# 2013-10-31 06:15:00, 白沙洲大道 (114.259519,30.440047), 有谁比我起得早，嗯？ 我在:白沙洲大道  显示地图
# 2013-10-29 09:36:00, 武汉·武汉科技大学 (114.26727,30.44067), 连续好几天都是7：30左右醒，本以为我的生物钟已经敲定，可昨晚关掉闹钟后今天就这个点才醒，噢，生物钟必须与闹钟配合才能更准o～ 我在这里:武汉·武汉科技大学  显示地图
# 2013-10-27 23:50:00, 知行路 (114.263999,30.436998), 祝亿帆风顺，祝一心一亿 我在:知行路  显示地图
# 2013-11-30 00:00:00, 民族大道 (114.396422,30.477919), 今日之突发事件，我爸坐车来武汉打工！这怎么可以！还好我行动果断，用我的霸道在付家坡把我爸拦截了然后又给送了回去，我爸已经平安到家我很高兴，我爱我的家人[呵呵]，我会用我的全部去爱他们保护他们❤！@呵呵，u my fml❤ 我在:民族大道  显示地图
# 2013-11-24 23:16:00, 民族大道 (114.39644,30.477713), 看《老有所依》看得好有感觉，，，明天又要上班了，啊，早睡～ 我在:民族大道  显示地图
# 2013-11-24 11:31:00, 民族大道 (114.396322,30.477562), 哪吒，，，， 我在:民族大道  显示地图 原图
# 2013-11-22 00:17:00, 软件园一路 (114.400347,30.473845), 停水停到我心里去了，，，，搜狗输入法用不了卡到我心里去了，，，，一天遇两件挫事，挫到心里去了，，， 我在:软件园一路  显示地图
# 2013-11-17 23:31:00, 民族大道 (114.396133,30.477339), 感觉自己就是大江上的一叶孤舟，还好我很坚强，come on baby. 我在:民族大道  显示地图
# 2013-11-22 00:17:00, 软件园一路 (114.400347,30.473845), 停水停到我心里去了，，，，搜狗输入法用不了卡到我心里去了，，，，一天遇两件挫事，挫到心里去了，，， 我在:软件园一路  显示地图
# 2013-11-17 23:31:00, 民族大道 (114.396133,30.477339), 感觉自己就是大江上的一叶孤舟，还好我很坚强，come on baby. 我在:民族大道  显示地图
# 2013-11-11 23:51:00, 民族大道 (114.396344,30.477156), 双11都是他们的，，，，，我都不知道买什么。 我在:民族大道  显示地图
# 2013-11-07 13:56:00, 软件园中路 (114.40347,30.481615), 现在上班的感觉就是时间过得挺快，学得挺慢，，， 我在:软件园中路  显示地图
# 2013-11-05 23:42:00, 民族大道 (114.397436,30.477216), 脚踏实地，，， 我在:民族大道  显示地图
# 2013-12-09 10:30:00, 南湖大道 (114.402063,30.480991), 周一总是好困好困，，，， 我在:南湖大道  显示地图
# 2013-12-03 22:40:00, 民族大道 (114.396384,30.47759), 以前柯鹏讲的选修课Oracle现在还经常用到，只是当时不听讲，数据库啊数据库，什么都可以不懂装懂，但这个必须好好懂。 我在:民族大道  显示地图
# 2013-11-30 00:00:00, 民族大道 (114.396422,30.477919), 今日之突发事件，我爸坐车来武汉打工！这怎么可以！还好我行动果断，用我的霸道在付家坡把我爸拦截了然后又给送了回去，我爸已经平安到家我很高兴，我爱我的家人[呵呵]，我会用我的全部去爱他们保护他们❤！@呵呵，u my fml❤ 我在:民族大道  显示地图
# 2013-11-24 23:16:00, 民族大道 (114.39644,30.477713), 看《老有所依》看得好有感觉，，，明天又要上班了，啊，早睡～ 我在:民族大道  显示地图
# 2013-12-27 15:14:00, 南湖大道 (114.401842,30.480903), 要是上班没有规定时间规定质量的任务，那我就可以长期来厕所磨蹭，此曰“划水”，，， 我在:南湖大道  显示地图
# 2013-12-27 00:33:00, 软件园三路 (114.401268,30.474922), 不愿睡觉，睡觉很无聊[睡觉][睡觉][睡觉] 我在:软件园三路  显示地图 原图
# 2014-01-07 17:22:00, 南湖大道 (114.401771,30.480876), 好烦躁，快点放假吧，，，熬不住了。。。 我在:南湖大道  显示地图
# 2014-01-06 22:50:00, 民族大道 (114.396014,30.477403), 每天晚上都会暗示自己要早睡，可每次都会拖到十一点之后的之后，，， 我在:民族大道  显示地图 原图
# 2014-01-05 13:08:00, 民族大道 (114.396102,30.477369), 每天都在与代码打交道，可是我想回家去吃饭，，， 我在:民族大道  显示地图
# 2014-01-01 23:15:00, 民族大道 (114.396301,30.47775), 真是悠闲的一天，不用上班，不用坐车回学校，什么都不用干，边晒太阳边玩电脑，真是舒服之极，想到明后上两天班后又是周末我真的是很开心啊，， 我在:民族大道  显示地图
# 2014-01-13 23:41:00, 民族大道 (114.395772,30.477416), 距离回家还有整整4天半，，， 我在:民族大道  显示地图
# 2014-01-13 23:32:00, 民族大道 (114.395989,30.477349), 立白洗衣液我是歌手第二季第一轮第二场竞演，，， 我在:民族大道  显示地图
# 2014-01-13 01:03:00, 民族大道 (114.396272,30.477053), 今夜之无眠：我感觉，我已经把委托，想得很明白了，却发现[睡觉]，我很难再睡着了😖，，， 我在:民族大道  显示地图
# 2014-01-18 12:51:00, 东环路 (112.210579,30.358429), 我大荆州的公交车竟然也会半路死机，我真是惊呆了，，， 我在:东环路  显示地图
#
# assistant
# The user likely lives in 民族大道 (114.396344, 30.477156).
# The user likely works/studies at 武汉·武汉科技大学 (114.26727, 30.44067) and 软件园中路 (114.40347, 30.481615).
# The user's work/study duration is from 9:36 am to 5:51 pm.
# system
#  You are a helpful AI assistant, answer the question as short as possible.
# user
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# The user likely lives in 位置, (longitude1, latitude1).
# The user likely works/studies at 位置, (longitude2, latitude2).
# The user's work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace. Number of workplace should not be more than 2.
# Do not answer anything else.
#
# Contents:
# 2013-05-14 18:12:00, 文心四路 (113.93586,22.517191), 我们都是生命的过客，辽远的天空难留下飞过的痕迹，带走的更不过是些微的记忆。生命会前行在历史的脉络上，沿途拾起一枝一叶，留待回忆；生命会走进时间的大门，所以，生命在时，追寻你的梦想，去你想去的地方，做一个想做的人，因为人生无常，因为生命只有一次。 我在:文心四路  显示地图 原图
# 2013-05-09 23:48:00, 海德一道 (113.929222,22.517271), 每晚睡前听你说晚安，是属于我的，最简单而持久的幸福。。。 我在:海德一道  显示地图 原图
# 2013-05-08 14:29:00, 020乡道 (100.194061,25.710407), 有时候，不小心知道了一些事，才发现自己所在乎的事是那么可笑。 我在:020乡道  显示地图 原图
# 2013-05-08 14:29:00, 北七路 (113.872184,22.621183), 回到深圳了，深圳的天气越来越不喜欢，阴天下雨 我在:北七路  显示地图 原图
# 2013-05-07 15:34:00, 022乡道 (100.173691,25.725021), 我是四个模样：一个是在朋友面前疯癫的样子，一个是在恋人面前完美的样子，一个是只身一人时脆弱的样子，还有一个，是在陌生的人群中安安静静的样子。 我在:022乡道  显示地图
# 2013-05-07 13:31:00, 021乡道 (100.188644,25.723679), 有时候，有个可以依靠的肩膀，和一个懂我的沉默的人，就是我唯一需要的。 我在:021乡道  显示地图 原图
# 2013-05-25 00:30:00, 步行一街 (113.92849,22.517445), 时间，不一定能证明许多东西，但一定会看透许多东西！ 我在:步行一街  显示地图
# 2013-05-23 01:07:00, 海德一道 (113.929222,22.517235), 我这人就有一个德性。只要别人不理我的，我不会再硬着脸皮去打扰。你的态度决定我的态度，你若对我沉默，对不起，我只好对你冷漠。 我在:海德一道  显示地图 原图
# 2013-05-14 18:12:00, 文心四路 (113.93586,22.517191), 我们都是生命的过客，辽远的天空难留下飞过的痕迹，带走的更不过是些微的记忆。生命会前行在历史的脉络上，沿途拾起一枝一叶，留待回忆；生命会走进时间的大门，所以，生命在时，追寻你的梦想，去你想去的地方，做一个想做的人，因为人生无常，因为生命只有一次。 我在:文心四路  显示地图 原图
# 2013-06-05 16:10:00, 041乡道 (100.103905,25.975487), 在不同的旅途中，我们背着行囊不断修行。人生四季，我们从懵懂到成熟，从纯真到清澈，从繁华到安宁，从学习、领悟到从容，一段旅程，整个过程必须亲自体验，才知道那是沙漠还是绿洲。 我在:041乡道  显示地图 [组图共3张] 原图
# 2013-05-31 02:09:00, 步行一街 (113.928528,22.517424), 真正的爱情不是一时好感，而是明明知道没结果，还想要坚持下去的冲动。 我在:步行一街  显示地图
# 2013-05-26 03:24:00, 后海滨路 (113.940742,22.518063), 酒，喝的半醉的好，喝的太多就醉了。爱，还是半真的好，爱的太深就心碎了。 我在:后海滨路  显示地图 原图
# 2014-08-12 01:18:00, 喜格孜步行街 (88.8759,29.2654), 在美景边喝下午茶🍵实在是太赞了！美景在路上…🚗 喜格孜步行街  显示地图 [组图共9张] 原图
# 2014-08-07 23:49:00, 解放东路 (91.132797,29.6427), 明天或者后天，有到林芝或者纳木错去的吗 解放东路  显示地图 [组图共5张] 原图
#
# assistant
# The user likely lives in 113.928497, 22.517691.
# The user likely works/studies at 113.929222, 22.517235.
# The user's work/study duration is from 00:23 to 01:04.
# system
#  You are a helpful AI assistant, answer the question as short as possible.
# user
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# The user likely lives in 位置, (longitude1, latitude1).
# The user likely works/studies at 位置, (longitude2, latitude2).
# The user's work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace. Number of workplace should not be more than 2.
# Do not answer anything else.
#
# Contents:
# 2012-05-20 22:16:00, 网页链接 (113.67533111,34.769294738), 我在这里:#郑州华美达广场国际酒店# 网页链接  显示地图 原图
# 2012-05-26 08:16:00, 网页链接 (113.67541735,34.769682299), 我在这里:#郑州市纬一路6号院# 网页链接  显示地图 原图
# 2012-05-24 00:46:00, 网页链接 (113.90218,35.31056), 我在这里:#牧野区二十二所生活区# 网页链接  显示地图 原图
# 2012-05-27 17:23:00, 网页链接 (113.67533111,34.769294738), 我在这里:#郑州华美达广场国际酒店# 网页链接  显示地图 原图
# 2012-05-26 20:46:00, 网页链接 (113.674987,34.770034), 我在这里:#星光公益站—陈坤（行走的力量）# 网页链接  显示地图 原图
# 2012-06-02 21:22:00, 郑州·省委二区 (113.67541735,34.769682299), 我在这里:#省委社区# 郑州·省委二区  显示地图 原图
# 2012-05-31 22:28:00, 网页链接 (113.67706,34.76934), 我在这里:#省委家属院10号院(南门)# 网页链接  显示地图 原图
# 2012-06-09 17:59:00, 郑州·省委二区 (113.67541735,34.769682299), 郑州市的纬三路中断，经六路到经七路之间的地段，这里没有一棵树，希望有关部门在这里种上行道树，也希望有关部门不要推委说这里种不了树！ 郑州·省委二区  显示地图 原图
# 2012-06-23 23:02:00, 北京·星光公益站之韩庚Love·Life (113.674507,34.77), 我在#星光公益站之吴奇隆（黑白能量）# 北京·星光公益站之韩庚Love·Life  显示地图
# 2012-06-30 18:59:00, 网页链接 (113.682533,34.786464), 纬三路，在经历了一个月的交通畅通和卫生整洁以后，又恢复了往日的拥堵与肮脏，政府做什么事为什么总是一阵风的，过去了就过去了啊？纬三路的停车混乱不是治理不了，而是政府不努力的坚持，最近一个月的顺畅与整洁，经八路街道办和交警确实付出了很多的努力和汗水，为什么不坚持？ 网页链接  显示地图
# 2012-08-13 04:34:00, 网页链接 (115.585853,34.906326), 北京西客站南广场的雕塑 我在:网页链接  显示地图
# 2012-08-23 20:31:00, 网页链接 (113.91072,35.30598), #七夕鹊桥会#我在鹊桥  @我要health和strong-build 茫茫人海相遇就是缘分啊! 放弃是一种胸怀，是一种成熟，是对自我内心的一种自信和把握。放弃，不是放弃追求，而是让人以豁达的心态去面对生活吧。❤ 网页链接  显示地图 原图
# 2012-08-24 15:58:00, 无 (113.848625,35.136489), 郑州的公交车上，座位有老弱病残孕专席，用黄色来与其他座位进行区分，所以在坐公交车的时候，如果您坐的座位是黄色，那么请您主动为老弱病残孕及抱小孩的市民让座，也请广大市民监督并主动提示占用座位的同志让座。这不是义务，这是一个公民必须做的最起码的道德底线。请扩散！  显示地图
# 2012-08-24 13:00:00, 网页链接 (113.8676388,35.3058215), 如果你有100万，买套房吧，收藏我们的爱情；你有10万，买辆车吧，驱动我们的爱情；你有1万，买个单反吧，见证我们的爱情；你有0.1万，去郊游吧，放飞我们的爱情；你有0.01万，吃次烛光晚餐吧，浪漫我们的爱情；你有0.001万，那就买瓶水吧，浇灌我们的爱情。 我在:网页链接  显示地图 原图
# 2012-08-26 17:59:00, 无 (113.678153,34.774166), 郑州市未来路和金水路交叉口，这里的brt旁边的人行道的中间，有个BRT的指示牌的台阶，已经严重影响市民出行安全，这个问题已经在建设BRT的时候提出来过，希望有关部门可以考虑把这个台子向北移动和远处的台子在同一位置，能够使斑马线中间没有障碍物，给市民有序安全的出行环境。  显示地图 原图
# 2012-08-29 19:04:00, 新乡·新乡市人民政府 (113.92657558,35.3027156), 新乡市的交通限速标志、道路禁停标志、禁止鸣笛标志等，都是设置在红绿灯位置，不仅美观大方，而且非常醒目，司机很容易看到，而在郑州，这些标志都是在道路中间的位置，并且隐藏在树荫中，故意让司机们看不到，希望交警部门注重城市交通管理细节，给市民一个快捷方便的出行环境！ 新乡·新乡市人民政府  显示地图 原图
#
# assistant
# The user likely lives in 郑州市省委二区 (113.67541735,34.769682299).
# The user likely works/studies at 北京·星光公益站之韩庚Love·Life (113.674507,34.77).
# The user's work/study duration is from 9:26 am to 17:59 pm.
# system
#  You are a helpful AI assistant, answer the question as short as possible.
# user
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# The user likely lives in 位置, (longitude1, latitude1).
# The user likely works/studies at 位置, (longitude2, latitude2).
# The user's work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace. Number of workplace should not be more than 2.
# Do not answer anything else.
#
# Contents:
# 2013-10-03 14:19:00, 梅山街 (114.032981,22.563879), 一叶知秋。南國的秋，不像北方的秋，来的迅猛、急切，浓烈而绚烂。而是星星點點，悄無聲息，需用心体察，才能感受。 我在:梅山街  显示地图 原图
# 2013-09-26 11:17:00, 梅山街 (114.032974,22.563871), 摄影不仅仅是光影、曝光，这些只是一种視觉表达手段。更应该是用这些手法讲故事！ 我在:梅山街  显示地图 [组图共3张] 原图
# 2013-09-16 22:42:00, 梅山街 (114.032981,22.563884), 摄影不是复制和创造，摄影在于选择与发现 我在:梅山街  显示地图 [组图共5张] 原图
# 2013-10-09 15:33:00, 梅山街 (114.032997,22.563888), 短暂，是因变化太快。我們才能感强烈的剧变。那种無法預料的来临、转瞬即失的夺目和無法挽留惜恋，才更弥足珍贵 我在:梅山街  显示地图 [组图共3张] 原图
# 2013-10-08 00:06:00, 梅山街 (114.032989,22.563886), 脚，承載着我們行走。每一双脚，都有一条生活轨迹。通過这一细节，我們看到了生活的悠闲与艰辛，看到了故事，也明白了细节的力量 我在:梅山街  显示地图 [组图共2张] 原图
# 2013-10-07 01:34:00, 梅山街 (114.032997,22.56389), 景深是因镜头焦距、参数的改变而產生的現象。合理、灵活的運用，可以丰富我們的表达手段，把平凡的景观创造的效果非凡。利用后景深创造空間感，利用前景深，创造梦幻效果。 我在:梅山街  显示地图 [组图共2张] 原图
# 2013-10-07 01:30:00, 梅山街 (114.033004,22.563898), 利用椰树、塔台等做前景，重新分割画面，利用人物、落日做視觉中心，使画面更具可读性 我在:梅山街  显示地图 [组图共3张] 原图
# 2013-10-05 00:25:00, 梅山街 (114.033004,22.563896), 再熟悉的景色，因時、因季节、因光线、因角度不同，以及我們自身审美趣味的提升，也會呈現我們曾未察觉的美。关键是要我們用心去发現。 我在:梅山街  显示地图 [组图共2张] 原图
# 2013-10-05 00:22:00, 梅山街 (114.032974,22.563871), 色彩在不光源和温度下，會產生偏移，恰恰给了我們将错就错的创造空間，利用色温、利用色彩的冷暖，不起眼的小景，便有了動人的視觉效果。生活也是这样，我們不能保証不犯错，关键是从错误中总结，这便成了以后成功的经验 我在:梅山街  显示地图 [组图共4张] 原图
# 2013-10-11 20:20:00, 梅山街 (114.033004,22.563896), 今生还是来世？過程与结果，哪个更让人淡薄欲念？哪个给人更多快乐。 我在:梅山街  显示地图 [组图共4张] 原图
# 2013-10-11 01:10:00, 梅山街 (114.032997,22.56389), 剪影的魅力 我在:梅山街  显示地图 [组图共4张] 原图
# 2013-10-10 14:48:00, 梅山街 (114.032989,22.56389), 人本身就是大自然杰之一。人具有丰富而完美的线条与形状。逆光给了我們化繁為簡的手段，也让人像更有韵味 我在:梅山街  显示地图 [组图共3张] 原图
# 2013-10-10 09:33:00, 梅山街 (114.032997,22.563894), 摄影与绘画最根本的區别在于，绘画可以無中生有地创造一个理想視界。而摄影只能拍現实中存在的一切。这就要求摄者“無所不用，學會取舍” 我在:梅山街  显示地图 [组图共3张] 原图
# 2013-10-09 21:57:00, 梅山街 (114.032974,22.563861), 有了这扇窗栅的阻隔，無論空隙有多么大、外面的陽光多灿烂，这世界在你眼里都改变了模样。學會使用这些窗栅，也将會為我們的視觉世界创造新奇 我在:梅山街  显示地图 [组图共2张] 原图
# 2013-10-18 22:51:00, 上街 (100.30980572727,30.939932090909), 昨晚一埸大雪，让色达银装素裹。清晨、雾中晨光下，婉如仙境。 我在:上街  显示地图 [组图共6张] 原图
# 2013-10-18 01:39:00, 甘孜藏族自治州色达县 (100.472127,32.151039), 队员说胸闷，半夜出来找氧气，遇到满天大雪 我在:甘孜藏族自治州色达县  显示地图 [组图共2张] 原图
#
# assistant
# The user likely lives in 梅山街 (114.032981, 22.563879).
# The user likely works/studies at 211省道 (101.87513936364, 30.895542090909) and 217省道 (100.080227, 29.286334).
# The user's work/study duration is from 01:30 am to 23:50 pm.
# system
#  You are a helpful AI assistant, answer the question as short as possible.
# user
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# The user likely lives in 位置, (longitude1, latitude1).
# The user likely works/studies at 位置, (longitude2, latitude2).
# The user's work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace. Number of workplace should not be more than 2.
# Do not answer anything else.
#
# Contents:
# 2015-08-15 12:35:00, 广州市 (113.29822,23.04469), 中国梦！！！ 最宏大的工程，最敢想的梦。 实现它的，中国我为你传播！！！ 广州市  显示地图 原图
# 2015-09-01 16:34:00, 网页链接 (113.29804,23.04458), 投诉竟然招到冻结我微博账号，这是怎样的问题怎样的处理？？？ 搞反了吧，我可是举报人。 网页链接  显示地图
# 2015-09-01 15:18:00, 广州市 (113.29821,23.0447), 沪指被乱改发布新闻，造成股民和市场恐慌，需要严肃处理责任人。 投诉还无法提交，包庇造谣者，一定要严查严查严查 广州市  显示地图 [组图共2张] 原图
# 2015-09-01 11:23:00, 广州市 (113.29814,23.04463), 一个人的成功需要无数人的支持，改变一个人的命运会创造出更多人的未来！！！ 广州市  显示地图
# 2015-09-03 03:15:00, 网页链接 (113.29814,23.04464), 晚安了！！！ 网页链接  显示地图 [组图共3张] 原图
# 2015-09-03 02:12:00, 网页链接 (113.29832,23.04463), #天下这么大，带我去看看# 抗战纪念日过后一起走世界，把爱传天下~ 网页链接  显示地图 [组图共8张] 原图
# 2015-09-03 02:10:00, 网页链接 (113.29826,23.04468), #天下这么大，带我去看看# 抗战纪念日过后一起走世界，把爱传天下~ 网页链接  显示地图 原图
# 2015-09-01 16:34:00, 网页链接 (113.29804,23.04458), 投诉竟然招到冻结我微博账号，这是怎样的问题怎样的处理？？？ 搞反了吧，我可是举报人。 网页链接  显示地图
# 2015-09-04 12:57:00, 网页链接 (113.29796,23.0445), #彭妈妈#对他#体贴#的#拥抱# 你们想要吗？？？ 网页链接  显示地图 原图
# 2015-09-04 12:48:00, 网页链接 (113.29796,23.0445), #小狗#爪#肉肉的#，让人#怎么#都#捏不够#...... 网页链接  显示地图 [组图共9张] 原图
# 2015-09-16 01:56:00, 网页链接 (113.29824,23.04472), 让#屌丝#拥有#高富帅#的#权力#和#便捷享受#【#芝麻信用#750分以上#支付宝#用户可走快速安检通道】在北京首都国际机场可以火速走国内快速安检通道（CIP通道）T1航站楼：二层2号门右侧首都空港贵宾休息室；T2航站楼：23号安检口/值机岛E岛F到之间；T3航站楼：安检区最左侧CIP通道。 网页链接  显示地图 [组图共4张] 原图
# 2015-09-16 01:38:00, 网页链接 (113.29807,23.0447), SpaceX和特斯拉两家公司的CEO#埃隆·马斯克#(Elon Musk)正式向美国联邦通信委员会(FCC)提出申请，发射#4000颗#近地轨道#卫星#，向全球提供#免费#的卫星#互联网#服务。#马斯克#更表示，向火星投射#核弹#是让#火星#适宜居住的方案，因为这是让火星变暖的#最最快速#的方法。 网页链接  显示地图 [组图共5张] 原图
# 2015-10-19 23:40:00, 广州 (113.29825,23.04472), 保千里 广州  显示地图
# 2015-10-21 10:54:00, 广州 (113.29825,23.04472), #华电能源# 广州  显示地图
# 2015-10-21 10:52:00, 广州 (113.29825,23.04472), #明星电缆# 广州  显示地图
# 2015-10-21 10:45:00, 广州 (113.29825,23.04472), #和邦生物# 广州  显示地图
# 2015-10-21 10:38:00, 广州 (113.29825,23.04472), #华银电力# 广州  显示地图
#
# assistant
# The user likely lives in Guangzhou, (113.29822, 23.04469).
# The user likely works/studies at, (113.29804, 23.04458).
# The user's work/study duration is from 9:00 am to 6:00 pm.
# system
#  You are a helpful AI assistant, answer the question as short as possible.
# user
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# The user likely lives in 位置, (longitude1, latitude1).
# The user likely works/studies at 位置, (longitude2, latitude2).
# The user's work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace. Number of workplace should not be more than 2.
# Do not answer anything else.
#
# Contents:
# 2012-08-12 16:52:00, 网页链接 (123.5273765,41.6578753), 回家咯…… 我在:网页链接  显示地图 原图
# 2012-12-12 21:47:00, 临园东街 (124.161491,39.871189), 这是一个需要学会自我推荐的时代，谦虚已经不能使人进步了… 我在:临园东街  显示地图 原图
# 2012-12-12 19:09:00, 临园东街 (124.159812,39.87405), 美丽的夜… 我在:临园东街  显示地图 原图
# 2012-12-12 12:14:00, 丹东·东港经济开发区 (124.15384,39.86737), #冬天style#雪中小景@天翼飞Young 我在这里：丹东·东港经济开发区  显示地图 原图
# 2012-12-12 12:13:00, 东港路大桥 (124.1529,39.872348), #冬天style#雪中小景@天翼飞Young 我在:东港路大桥  显示地图 原图
# 2012-12-12 07:33:00, 东港路大桥 (124.152061,39.873062), 早！ 我在:东港路大桥  显示地图 原图
# 2013-01-09 19:50:00, 临园东街 (124.162368,39.872756), 世界很大，圈子很小 我在:临园东街  显示地图 原图
# 2013-01-08 20:25:00, 丹东·东港经济开发区 (124.15384,39.86737), 温馨的夜 我在这里:丹东·东港经济开发区  显示地图 原图
#
# assistant
# The user likely lives in 临园东街 (124.16146, 39.875183).
# The user likely works/studies at 丹东·东港经济开发区 (124.15384, 39.86737) and 东港路大桥 (124.1529, 39.872348).
# The user's work/study duration is from 7:00 am to 6:00 pm.
# system
#  You are a helpful AI assistant, answer the question as short as possible.
# user
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# The user likely lives in 位置, (longitude1, latitude1).
# The user likely works/studies at 位置, (longitude2, latitude2).
# The user's work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace. Number of workplace should not be more than 2.
# Do not answer anything else.
#
# Contents:
# 2012-01-01 00:47:00, 网页链接 (114.32588,30.35242), 不掺任何的表演，轰轰烈烈那几年，传说中的2012就那么安静的到来，祝大家新年前程似锦，平平安安！！！ 网页链接  显示地图
# 2012-02-09 15:07:00, 网页链接 (114.40458,30.50675), 我在这里:#武汉市-洪山区#蹭无线网 网页链接  显示地图
# 2012-04-03 10:36:00, 网页链接 (114.33534,30.348894), 我在#中国地质大学江城学院#，看看还有谁来过这里。网页链接    显示地图
# 2012-04-03 10:35:00, 网页链接 (114.33416,30.347775), 我在#中国地质大学江城学院(西门)#，wuhan 网页链接    显示地图
# 2012-04-03 10:34:00, 网页链接 (114.41366,30.507902), 我获得了【Let's Linsanity】勋章，冷板凳挡不住我疯狂的脚步，现在就踏上球场打破沉默，Let's Linsanity! 网页链接   显示地图 原图
# 2012-04-03 10:34:00, 网页链接 (114.41366,30.507902), 我开始玩微领地啦！初次签到，获得微领地【一鸣惊人】勋章，快跟我一起探索城市吧！加油，一切从这里开始！ 网页链接   显示地图 原图
# 2012-04-03 10:33:00, 网页链接 (114.41366,30.507902), 我在#华中科技大学#，看看还有谁来过这里。网页链接    显示地图
# 2012-04-03 09:48:00, 网页链接 (114.33532,30.34888), 我在这里:#中国地质大学江城学院#附近 网页链接  显示地图
# 2012-04-06 11:02:00, 网页链接 (114.3104,30.54021), 我在#中南财经大学体育场#，看看还有谁来过这里。网页链接    显示地图
# 2012-04-07 14:40:00, 网页链接 (114.33435,30.34736), 我在#中国地质大学江城学院党委学生工作部(处)#，看看还有谁来过这里。网页链接    显示地图
# 2012-04-07 14:33:00, 网页链接 (114.41366,30.507902), 我获得了@微领地 的初战告捷勋章，这个你也可以有！网页链接    显示地图 原图
# 2012-04-07 14:32:00, 网页链接 (114.41366,30.507902), 我在@微领地 成为#华中科技大学#的领主，想来挑战么？网页链接    显示地图
# 2012-04-07 14:30:00, 网页链接 (114.33416,30.347775), 我在#中国地质大学江城学院(西门)#，看看还有谁来过这里。网页链接    显示地图
# 2012-04-08 13:41:00, 网页链接 (114.33416,30.347775), 我在@微领地 成为#中国地质大学江城学院(西门)#的领主，想来挑战么？网页链接    显示地图
# 2012-04-08 13:40:00, 网页链接 (114.33416,30.347775), 我获得了@微领地 的捷报频传勋章，这个你也可以有！网页链接    显示地图 原图
# 2012-04-08 13:39:00, 网页链接 (114.33435,30.34736), 我在@微领地 成为#中国地质大学江城学院党委学生工作部(处)#的领主，想来挑战么？网页链接    显示地图
# 2012-04-08 22:24:00, 网页链接 (114.41366,30.507902), 我在#华中科技大学#，看看还有谁来过这里。网页链接    显示地图
# 2012-04-08 22:23:00, 网页链接 (114.3104,30.54021), 我在@微领地 成为#中南财经大学体育场#的领主，想来挑战么？网页链接    显示地图
# 2012-04-08 22:23:00, 网页链接 (120.893654,32.008636), 我在#南通职业大学#，看看还有谁来过这里。网页链接    显示地图
# 2012-04-10 06:28:00, 网页链接 (114.333565,30.346706), 我在这里:#武汉市-江夏区# 网页链接  显示地图
# 2012-04-10 22:18:00, 网页链接 (114.33416,30.347775), 我在#中国地质大学江城学院(西门)#，看看还有谁来过这里。网页链接    显示地图
# 2012-04-11 06:50:00, 网页链接 (120.893654,32.008636), 我在#南通职业大学#，看看还有谁来过这里。网页链接    显示地图
# 2012-04-11 06:50:00, 网页链接 (114.3104,30.54021), 我在#中南财经大学体育场#，看看还有谁来过这里。网页链接    显示地图
# 2012-04-11 06:49:00, 网页链接 (114.33416,30.347775), 我在#中国地质大学江城学院(西门)#，看看还有谁来过这里。网页链接    显示地图
# 2012-04-11 06:49:00, 网页链接 (114.3164,30.42275), 我在#武汉大学东湖分校#，看看还有谁来过这里。网页链接    显示地图
# 2012-04-10 22:21:00, 网页链接 (114.3164,30.42275), 我在#武汉大学东湖分校#，看看还有谁来过这里。网页链接    显示地图
# 2012-04-10 22:19:00, 网页链接 (120.893654,32.008636), 我获得了@微领地 的攻城拔寨勋章，这个你也可以有！网页链接    显示地图 原图
# 2012-04-10 22:19:00, 网页链接 (120.893654,32.008636), 我在@微领地 成为#南通职业大学#的领主，想来挑战么？网页链接    显示地图
# 2012-04-12 06:48:00, 网页链接 (114.33416,30.347775), 我在#中国地质大学江城学院(西门)#，看看还有谁来过这里。网页链接    显示地图
# 2012-04-11 22:21:00, 网页链接 (114.3164,30.42275), 我在#武汉大学东湖分校#，看看还有谁来过这里。网页链接    显示地图
#
# assistant
# The user likely lives in 武汉市-江夏区 (114.333565, 30.346706).
# The user likely works/studies at 中国地质大学江城学院(西门) (114.33416, 30.347775).
# The user's work/study duration is from 9:48 am to 6:50 pm.
# system
#  You are a helpful AI assistant, answer the question as short as possible.
# user
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# The user likely lives in 位置, (longitude1, latitude1).
# The user likely works/studies at 位置, (longitude2, latitude2).
# The user's work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace. Number of workplace should not be more than 2.
# Do not answer anything else.
#
# Contents:
# 2012-02-19 16:27:00, 网页链接 (114.03706,22.532022), 我在这里: #深圳市-福田区# 网页链接  显示地图
# 2012-02-21 12:36:00, 网页链接 (120.18195,30.26053), 我在这里: #杭州市-下城区#名家厨房等位中！ 网页链接  显示地图
# 2012-02-25 11:41:00, 网页链接 (120.27028,30.21351), 我在这里: #杭州市-萧山区#精致酒店，精致的有香港酒店的感觉！ 网页链接  显示地图 原图
# 2012-02-27 14:03:00, 网页链接 (113.51441,22.12), 我在这里: #珠海市-香洲区#吃饭！ 网页链接  显示地图
# 2012-02-26 15:52:00, 网页链接 (120.44042,30.23355), 我在这里: #杭州市-萧山区#回深圳，机场候机中！ 网页链接  显示地图
# 2012-02-26 11:14:00, 网页链接 (120.16504,30.27113), 我在这里: #杭州市-拱墅区# 网页链接  显示地图
# 2012-03-02 19:24:00, 平远北街 (113.11814,23.00424), 我在这里: #佛山市-禅城区#珠江鱼邨晚餐！ 平远北街  显示地图
# 2012-03-09 15:32:00, 网页链接 (114.08773,22.54662), 我在这里: #深圳市-福田区#曼哈电子商城！ 网页链接  显示地图
# 2012-03-06 17:31:00, 网页链接 (114.035957,22.541410), 我在这里: #顺德佬·天心酒楼香蜜湖店# 网页链接  显示地图
# 2012-03-10 02:44:00, 网页链接 (120.27885,30.20944), 我在这里: #杭州市-萧山区#南苑e家休息！ 网页链接  显示地图
# 2012-03-09 21:03:00, 网页链接 (113.814064,22.646202), 我在这里: #深圳市-宝安区#宝安机场国航贵宾室！ 网页链接  显示地图
# 2012-03-11 16:12:00, 网页链接 (120.16267,30.280828), 我在这里: #杭州市-下城区#杭州这个时间的士交班，终于打上一台车！ 网页链接  显示地图
# 2012-03-10 16:05:00, 网页链接 (120.25302,30.21675), 我在这里: #杭州市-萧山区#温馨的榻榻米！ 网页链接  显示地图 原图
# 2012-03-13 20:24:00, 网页链接 (113.820038,22.642380), 我在这里: #宝安机场B楼东航贵宾室#一个人的贵宾室 网页链接  显示地图 原图
# 2012-03-16 23:50:00, 环城北路 (120.16222,30.275566), 我在这里: #杭州市-下城区#朝晖路菲斯泰尔酒店！ 环城北路  显示地图
# 2012-03-16 12:34:00, 网页链接 (120.163612,30.276730), 我在这里: #浙江自然博物馆# 网页链接  显示地图
# 2012-03-18 00:01:00, 网页链接 (120.16214,30.275482), 一直以来都有㝍一部长篇的想法，名字就叫「天堂里的罪恶」，争取早一点动笔！我在这里: #杭州市-下城区# 网页链接  显示地图
# 2012-03-17 18:49:00, 网页链接 (120.16489,30.279129), 我在这里: #杭州市-下城区#朝晖路，准备吃饭！ 网页链接  显示地图
# 2012-03-20 16:33:00, 网页链接 (113.820038,22.642380), 我在这里: #宝安机场B楼东航贵宾室# 网页链接  显示地图
# 2012-03-22 17:34:00, 网页链接 (120.435097,30.233559), 我在这里: #杭州萧山国际机场新航站楼# 网页链接  显示地图 原图
# 2012-03-23 02:27:00, 网页链接 (117.35261,39.143497), 我在这里: #东丽区#落地天津！ 网页链接  显示地图
# 2012-03-22 22:59:00, 网页链接 (120.437782,30.23543), 我在这里: #杭州萧山国际机场#航班延误 网页链接  显示地图 原图
# 2012-03-24 15:22:00, 网页链接 (120.630348,31.32469), 我在这里: #苏州拙政园#3 网页链接  显示地图 原图
# 2012-03-24 15:22:00, 网页链接 (120.630348,31.32469), 我在这里: #苏州拙政园#2 网页链接  显示地图 原图
# 2012-03-24 15:19:00, 网页链接 (120.630348,31.32469), 我在这里: #苏州拙政园# 网页链接  显示地图 原图
# 2012-03-24 13:23:00, 网页链接 (120.629905,31.315191), 我在这里: #苏州市-平江区#午饭！ 网页链接  显示地图 原图
# 2012-03-24 08:21:00, 网页链接 (120.268646,30.209261), 我在这里: #德嘉精致酒店#准备出发！ 网页链接  显示地图
# 2012-03-23 22:26:00, 网页链接 (120.271957,30.206495), 我在这里: #新时代大酒店#等待宵夜 网页链接  显示地图
# 2012-03-23 14:59:00, 网页链接 (117.3592,39.130402), 我在这里: #天津滨海国际机场(出发)#天津机场好冷淸，根本没有直辖巿的感觉！ 网页链接  显示地图
# 2012-03-23 11:34:00, 网页链接 (117.201393,39.098728), 我在这里: #天津金融大厦(西门)#我曾经工作过的地方！ 网页链接  显示地图 原图
#
# assistant
# The user likely lives in Shenzhen, (114.03706, 22.532022).
#
# The user likely works/studies at Hangzhou, (120.16267, 30.280828) and possibly also at another location in Suzhou, (120.630348, 31.32469).
#
# The user's work/study duration is from around 8am to 6pm.
# system
#  You are a helpful AI assistant, answer the question as short as possible.
# user
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# The user likely lives in 位置, (longitude1, latitude1).
# The user likely works/studies at 位置, (longitude2, latitude2).
# The user's work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace. Number of workplace should not be more than 2.
# Do not answer anything else.
#
# Contents:
# 2012-01-12 06:39:00, 网页链接 (113.202,23.37933), 回家...我在这里:#广州市-花都区# 网页链接  显示地图 原图
# 2012-04-05 11:57:00, 网页链接 (114.0405,22.644613), 好像到中午了 回去吃饭吧我在这里:#深圳市-宝安区# 网页链接  显示地图
# 2012-04-18 09:13:00, 网页链接 (114.02943,22.611), 我在这里:#深圳北站#这里好大呀 网页链接  显示地图
# 2012-07-06 17:01:00, 网页链接 (114.015258,22.739828), 太萌了！！！ 网页链接  显示地图 原图
# 2012-07-22 13:59:00, 网页链接 (114.001586,22.732271), 台风来啦！ 网页链接  显示地图
# 2013-11-24 10:11:00, 苏州·昆山南站 (120.955977365,31.3530355698), 第二站。 我在这里:苏州·昆山南站  显示地图
# 2013-11-30 19:37:00, 苏州·金鸡湖音乐喷泉 (120.68153226,31.318017511), 马上就可以看音乐喷泉啦！ 我在这里:苏州·金鸡湖音乐喷泉  显示地图
# 2013-12-01 23:22:00, 苏州·新屹大厦公交站 (120.65458,31.34055), 你好，陌生人。 我在这里:苏州·新屹大厦公交站  显示地图
# 2013-12-14 22:17:00, 苏州北枢纽 (120.652513,31.345639), 小店的农夫山泉好贵。用@我查查条码比价 一看就知，@蔡佳敏XOXO @girl-西爷 @JENNY_Mooo @末-初 快来围观哇。。。 我在:苏州北枢纽  显示地图 原图
#
# assistant
# The user likely lives in 体育东路, (113.327751, 23.131519).
# The user likely works/studies at 深圳·光明农场, (113.94913, 22.76481).
# The user's work/study duration is from 11:28 am to 13:27 pm.
# system
#  You are a helpful AI assistant, answer the question as short as possible.
# user
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# The user likely lives in 位置, (longitude1, latitude1).
# The user likely works/studies at 位置, (longitude2, latitude2).
# The user's work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace. Number of workplace should not be more than 2.
# Do not answer anything else.
#
# Contents:
# 2012-08-22 09:14:00, 网页链接 (116.595832,39.913074), 小区里的流浪咪，ms以前没见过…警惕性很高,离着那么远拍照都跑开了… 我在:网页链接  显示地图 原图
# 2012-08-21 11:20:00, 网页链接 (116.594215,39.913085), 晴好天…洗衣日 我在:网页链接  显示地图
# 2012-09-02 15:02:00, 网页链接 (116.407325,39.915454), 看演出前逛了两小时街…真累…坐下就困…[睡觉] 我在:网页链接  显示地图
# 2012-09-24 09:49:00, 管庄路 (116.590652,39.923809), 邮局拿号…前面居然有70个人在等候~ 我在:管庄路  显示地图
# 2012-09-30 09:37:00, 网页链接 (116.647033,39.776382), 京津还算通畅… 我在:网页链接  显示地图
# 2012-09-30 09:00:00, 网页链接 (116.688926,39.924228), 上高速喽… 我在:网页链接  显示地图
# 2012-10-01 20:48:00, 朝阳路辅路 (116.595779,39.91312), 斯蒂芬金的故事贩卖机…第一个故事就吓到我了，不适合天黑后读的故事，尤其对于越年长越胆小的人… 我在:朝阳路辅路  显示地图
# 2012-09-30 15:16:00, 网页链接 (117.028686,38.796283), 河北出事故…堵到天津界…我们返航了~身随心动…爷换地方过节去… 我在:网页链接  显示地图
# 2012-10-03 12:49:00, 网页链接 (116.513618,40.95058), 分享图片 我在:网页链接  显示地图 原图
# 2012-10-05 21:41:00, 朝阳路辅路 (116.595787,39.914188), 给小朋友们准备的明天午餐，第一次用模具做饭团，偷懒随便撕了点海苔放上，败笔啊!一很丑有木有?我会告诉你是小汽车和小鱼造型的饭团么?会么?会么? 我在:朝阳路辅路  显示地图 原图
# 2013-02-28 11:05:00, 朝阳路 (116.602294,39.912734), 雾霾天，口罩人。 我在:朝阳路  显示地图 原图
# 2013-03-02 20:01:00, 金盏路 (116.571533,40.002922), 夜场温泉，人少灯昏暗，水幕电影也雾蒙蒙 我在:金盏路  显示地图 原图
#
# assistant
# The user likely lives in 朝阳路辅路 (116.595787, 39.914188).
# The user likely works/studies at 双桥东路环岛 (116.597106, 39.915138) and 朝阳北路 (116.595191, 39.923465).
# The user's work/study duration is from 8:01 am to 6:00 pm.
# system
#  You are a helpful AI assistant, answer the question as short as possible.
# user
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# The user likely lives in 位置, (longitude1, latitude1).
# The user likely works/studies at 位置, (longitude2, latitude2).
# The user's work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace. Number of workplace should not be more than 2.
# Do not answer anything else.
#
# Contents:
# 2011-10-16 08:11:00, 无 (115,115), 崭新的一天又开始了，大家早安！  显示地图 原图
# 2012-02-27 11:20:00, #Camera360分享图片# (115.6927,28.16465), 丰城到樟树出现了史无前例的交通拥堵，一天长龙就这样毫不情愿的出现在了105国道上。 #Camera360分享图片#  显示地图 原图
# 2012-03-22 23:21:00, 网页链接 (116.35523,27.97943), 我在这里:#东华理工学院南区#@金立手机 网页链接  显示地图 原图
# 2012-03-15 00:45:00, 网页链接 (116.355644,27.979753), 我的位置  江西省抚州市临川区玉茗大道191号 分享自[高德地图] 网页链接  显示地图
# 2012-02-29 08:06:00, #Camera360分享图片# (115.7781,28.20737),  #Camera360分享图片#  显示地图 原图
# 2012-03-28 22:25:00, 网页链接 (116.355667,27.980491), 我在这里:#抚州市街拍的一辆跑车，标致的 网页链接  显示地图 原图
# 2012-04-11 19:40:00, #Camera360随手拍# (116.3507,27.98369), 铁达尼号，感人的爱情再一次重现 #Camera360随手拍#  显示地图 原图
# 2012-04-10 20:40:00, #Camera360随手拍# (116.3507,27.98369), 现在外面是狂风暴雨啊 #Camera360随手拍#  显示地图 原图
# 2012-04-10 14:11:00, #Camera360随手拍# (116.3507,27.98369),. #Camera360随手拍#  显示地图 原图
# 2012-04-10 11:34:00, #Camera360随手拍# (116.3507,27.98369), 生活的态度，你是什么样的态度呢？ #Camera360随手拍#  显示地图 原图
# 2012-04-16 11:07:00, 网页链接 (116.355369,27.980955), 五一我在这里:#抚州市区#来了 网页链接  显示地图 原图
# 2012-04-11 20:34:00, #Camera360随手拍# (116.3507,27.98369), 生命是可贵的，只有一次，珍惜生命里的每时每刻 #Camera360随手拍#  显示地图 原图
# 2012-07-03 10:42:00, 网页链接 (115.905372,28.67163),  @爱幻想的瑶小瑶 网页链接  显示地图 原图
# 2015-10-06 13:04:00, 深圳·深圳凯宾斯基酒店 (113.939392,22.518), 难道你不心动#东莞无痕接发##上海无痕接发哪里最好##北京无痕接发大胜# 深圳·深圳凯宾斯基酒店  显示地图 [组图共3张] 原图
# 2015-10-06 12:50:00, 深圳·深圳凯宾斯基酒店 (113.939392,22.518), 我们不但专长无痕接发 而且还专业剪发#深圳剪头发哪里好##深圳接发哪里好##香港烫发##香港无痕接发创始人##东莞哪里烫发好# 深圳·深圳凯宾斯基酒店  显示地图 [组图共6张] 原图
# 2015-10-06 12:48:00, 深圳·深圳凯宾斯基酒店 (113.939392,22.518), 凡要喜欢就好#深圳无痕接发##澳门烫发##香港代购现场直播##香港烫发# 深圳·深圳凯宾斯基酒店  显示地图 [组图共3张] 原图
# 2015-10-06 11:59:00, 深圳·深圳凯宾斯基酒店 (113.939392,22.518), 改变是美好的#深圳无痕接发##深圳烫发技术哪家强##澳门染发# 深圳·深圳凯宾斯基酒店  显示地图 原图
# 2015-10-06 11:57:00, 网页链接 (113.938087,22.51807), 生活就该多些色彩#澳门染发##澳门接发##深圳无痕接发##东莞染发# 网页链接  显示地图 [组图共2张] 原图
# 2015-10-06 11:45:00, 深圳·海岸城美食 (113.937042,22.517651), 听说好看的发型能改变坏心情哦#东莞无痕接发##佛山无痕接发# 深圳·海岸城美食  显示地图 [组图共3张] 原图
# 2015-10-06 11:44:00, 深圳·海岸城美食 (113.937042,22.517651), #东莞无痕接发##深圳无痕接发# 心情美美哒 深圳·海岸城美食  显示地图 [组图共2张] 原图
# 2015-10-05 17:53:00, 深圳·海岸城美食 (113.937042,22.517651), 魅力就像你身后的影子，你追不到，但是只要你往前走，它✨就会一直跟在你身后#深圳烫发技术哪家强##跑男深圳##花千骨2015##邓超好队长# 深圳·海岸城美食  显示地图 [组图共4张] 原图
# 2015-10-13 11:06:00, 深圳 (113.938087,22.51808), 你不懂我的灵感来自何方#深圳无痕接发##深圳染发##澳门无痕接发##广州无痕纳米接发##上海无痕接发哪里最好# 深圳  显示地图 [组图共6张] 原图
#
# assistant
# The user likely lives in 深圳·南油 (113.92588, 22.522539).
# The user likely works/studies at 深圳·海岸城美食 (113.937042, 22.517651).
# The user's work/study duration is from 11:34 AM to 8:08 PM.
# system
#  You are a helpful AI assistant, answer the question as short as possible.
# user
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# The user likely lives in 位置, (longitude1, latitude1).
# The user likely works/studies at 位置, (longitude2, latitude2).
# The user's work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace. Number of workplace should not be more than 2.
# Do not answer anything else.
#
# Contents:
# 2015-11-06 05:18:00, 深圳·文锦花园 (114.127197,22.546021), 为什么夜深了 我缺越来越精神 ，长夜漫漫无心睡眠 深圳·文锦花园  显示地图
# 2015-11-23 08:44:00, 深圳·民治街区 (114.032791,22.614519), 周一了 为下一场发布会准备吧 深圳·民治街区  显示地图 [组图共2张] 原图
# 2015-11-22 01:23:00, 东莞·大屏嶂森林公园 (114.01757,22.78602), 当你结束一项任务 放松去感受快乐 发现一切都是那么快乐如意 ， 加油 亲人们 爱你们 东莞·大屏嶂森林公园  显示地图 [组图共7张] 原图
# 2015-11-21 11:20:00, 深圳·观澜街区 (114.040497,22.736919), 时尚大牌 典雅舒适 15小时来了 美女们不用怕在剁手了，男人绝不会再让你剁手 深圳·观澜街区  显示地图 [组图共8张] 原图
# 2015-11-20 17:14:00, 深圳·桃源街区 (113.981339,22.609921),  深圳·桃源街区  显示地图 [组图共2张] 原图
# 2015-12-02 02:42:00, 深圳·文锦花园 (114.127197,22.546021), 深圳·文锦花园★★★★★，睡不着了 深圳·文锦花园  显示地图
# 2015-11-29 14:20:00, 深圳·文锦花园 (114.127197,22.546021), 周末绿道漫步 孩子们非常开心， 深圳·文锦花园  显示地图 [组图共8张] 原图
# 2015-11-28 07:19:00, 深圳·文锦花园 (114.127197,22.546021), 15小时场合服饰女装品牌2016春夏新品发布暨招商推广加盟会于2015年11月21日在深圳市麒麟山庄隆重  品牌创始人“马氏三姐妹”现场接受多家媒体采访。   15小时在此次的发布会上与中国量化美学专业机构北京美目世纪达成战略合作，量化美学开创第一人韩久九老师也出任15小时顾问 深圳·文锦花园  显示地图 [组图共4张] 原图
# 2015-12-07 19:06:00, 深圳·深圳市文化馆 (114.087502,22.549681), 现在的孩子太幸福了 深圳·深圳市文化馆  显示地图 [组图共4张] 原图
# 2015-12-21 09:12:00, 深圳·观澜街区 (114.040497,22.7367), 圣诞服装 深圳·观澜街区  显示地图 [组图共5张] 原图
# 2015-12-21 09:11:00, 深圳·观澜街区 (114.040497,22.7367), 简单明了 深圳·观澜街区  显示地图 原图
#
# assistant
# The user likely lives in 深圳·文锦花园 (114.127197, 22.546021).
# The user likely works/studies at 深圳·民治街区 (114.040382, 22.608589) and 深圳·东门商业圈 (114.131699, 22.54397).
# The user's work/study duration is from 08:38 to 20:34.
# system
#  You are a helpful AI assistant, answer the question as short as possible.
# user
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# The user likely lives in 位置, (longitude1, latitude1).
# The user likely works/studies at 位置, (longitude2, latitude2).
# The user's work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace. Number of workplace should not be more than 2.
# Do not answer anything else.
#
# Contents:
# 2015-10-05 01:17:00, 内江·威远县 (104.668884,29.527474), 中秋+十一，两个节吃货都会吃够啦。每天几场酒席，不知往哪跑哪！ 内江·威远县  显示地图
# 2015-10-26 20:34:00, 内江·严陵镇 (104.66116,29.52046), 这年头的人，咋都给钱有仇吗！生死不相依……如此下去，俺国是不是不好玩了😭😭😭😭 内江·严陵镇  显示地图
# 2015-10-26 01:35:00, 内江 (104.53353,29.64227), 内江★★★★★，天府腹地，鱼米香浓，文帝书香，终归内江。 内江  显示地图
#
# assistant
# The user likely lives in 内江 (104.53353, 29.64227).
# The user likely works/studies at 内江·威远中学校 (104.66365, 29.51501) or 内江·四川省川威集团有限公司 (104.49077, 29.72732).
# The user's work/study duration is from 08:00 am to 17:00 pm.
# system
#  You are a helpful AI assistant, answer the question as short as possible.
# user
#  The following is a record of posts made by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post.
# Your task is to find the user's home, workplace or school, and work duration.
# You should judge the type of the user's current location based on time and the content of the post, and determine the user's usual work duration based on the time of location switching. If you don't have enough information, don't jump to conclusions.
# Your answer should include detailed location and precise coordinates and time, for example:
#
# The user likely lives in 位置, (longitude1, latitude1).
# The user likely works/studies at 位置, (longitude2, latitude2).
# The user's work/study duration is from -- am to -- pm.
#
# Tip: The location that often appears at midnight is likely to be home. Some users are freelancers and their home is their workplace. Number of workplace should not be more than 2.
# Do not answer anything else.
#
# Contents:
# 2015-12-31 10:03:00, 无 (114.02652,22.535067), 如果自己不够强大，那么再好的猎物送到你眼前，你一样也无计可施。 深圳·天济大厦  显示地图 原图
# 2015-12-31 07:37:00, 无 (114.098747,22.579269), 2015年只剩下不到17小时了，马上就要说再见了。不管这一年，顺利还是失意，快乐或是伤心，都打点好心情，准备迎接2016年吧！留下遗憾和伤悲，带上梦想和努力，拥抱新的一年！ 深圳·清水河街区  显示地图 原图
# 2015-12-30 07:58:00, 无 (114.105911,22.57831), 原来没有所谓的泼妇。 深圳·清水河街区  显示地图 原图
# 2015-12-29 13:22:00, 无 (114.089211,22.541889), 穷人有穷人的乐 深圳·华强北  显示地图 原图
# 2015-12-27 18:36:00, 无 (114.09874,22.57922), 再也不怕手机没电了。 深圳·清水河街区  显示地图 原图
# 2015-12-26 07:46:00, 无 (114.104141,22.57432), 生活不是一场赛跑，生活是一场旅行，要懂得好好欣赏每一段的风景。 深圳·清水河街区  显示地图 原图
# 2015-12-25 06:50:00, 无 (114.098763,22.57929), 没人是完全自由的，即使是鸟儿，也有天空的约束。 深圳·清水河街区  显示地图 原图
# 2015-12-24 07:59:00, 无 (114.10585,22.57811), 好心情才会有好风景，好眼光才会有好发现，早安！ 深圳·清水河街区  显示地图
# 2015-12-23 08:03:00, 无 (114.097427,22.572222), 人生最大的遗憾，莫过于错误的坚持，和轻易的放弃。各位，早安… 深圳·深圳市第一建筑工程公司住宅区  显示地图 原图
# 2015-12-22 07:34:00, 无 (114.098763,22.57921), 生命是一种回声。你把最好的给予别人，就会从别人那里获得最好的。你帮助的人越多，你得到的也越多。各位早安！ 深圳·清水河街区  显示地图 原图
# 2015-12-20 19:03:00, 无 (114.111153,22.62248), 年底了，大家在取钱时，一定要注意保护密码，来，给亲们一个标准的动作示范..不用感谢我，请叫我雷锋 ......～ 深圳·中海怡翠  显示地图 原图
# 2015-12-08 08:26:00, 无 (114.092773,22.55587), 成为自己想成为的人，这从来不迟。各位，早安… 深圳·八卦岭  显示地图
#
# assistant
# The user likely lives in 清水河街区, (114.09874, 22.57929).
# The user likely works/studies at 深圳市第一建筑工程公司住宅区, (114.097427, 22.572222) and 华强北, (114.089211, 22.541889).
# The user's work/study duration is from 7:00 am to 8:00 pm.

# %%
output_dir = "output"  # 指定输出目录

output_filename = os.path.join(output_dir, f"output_{i}.txt")
# 创建空文件（如果文件不存在）
with open(output_filename, "a+", encoding="utf-8") as f:
    pass  # 不需要写入任何内容，只是创建文件
with open(output_filename, "w", encoding="utf-8") as f:
    f.write(op)

# %%
messages = [
    {"role": "system", "content": 'Answer question as short as possible.'},
    {"role": "user", "content": [
        #{"type": "image"},
        {"type": "text", "text": new_text}
    ]}
]
input_text = processor.apply_chat_template(messages, add_generation_prompt=True)
inputs = processor(
    #image,
    text = input_text,
    add_special_tokens=False,
    return_tensors="pt"
).to(model.device)

output = model.generate(**inputs, max_new_tokens=256)
print(processor.decode(output[0]))
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 29 Oct 2024
#
# Answer question as short as possible.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# The following is a record of posts published by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post. Your task is to find the user's points of interest, including but not limited to the location of the user's home, workplace, school, places they often go to, and the coordinate types of these places. The location should be as detailed as possible, the coordinates must be given, and the province and city should be included as much as possible. You should combine the content of the post to determine the type of the user's current location. If you do not have enough information, do not easily draw conclusions.
#
# Contents:
# 2015-03-27 13:51:00, 无 (0,0), 落日余晖，美好整个城市。  我正在使用"城市余晖"封面图，好漂亮，你们都快来试试！网页链接  原图
# 2015-04-03 19:29:00, 深圳·龙岗区老干中心 (114.23048652799,22.717405002209), 吃自助如果你喝可乐你就输了，因为还没有认真奋斗就饱了[撇嘴][撇嘴] 深圳·龙岗区老干中心  显示地图 原图
# 2015-03-06 01:38:00, 深圳·龙岗区老干中心 (114.23048652799,22.717405002209), 배고파 죽겠어요! 深圳·龙岗区老干中心  显示地图
# 2015-03-05 16:26:00, 深圳·龙岗区老干中心 (114.23048652799,22.717405002209), 每天都是饿到胃疼，才记得起来！！！！ 深圳·龙岗区老干中心  显示地图
# 2015-03-03 16:47:00, 深圳·龙岗区老干中心 (114.23048652799,22.717405002209), 一觉睡到现在，要不是肚子一直叫，都忘了醒来 深圳·龙岗区老干中心  显示地图
# 2015-03-03 06:41:00, 深圳·龙岗区老干中心 (114.23048652799,22.717405002209), 终于可以睡觉了！！！！ 深圳·龙岗区老干中心  显示地图
# 2015-03-02 13:43:00, 深圳·龙岗区老干中心 (114.23048652799,22.717405002209), 上个夜班，累到全身发痛！命苦啊！ 深圳·龙岗区老干中心  显示地图
# 2015-02-28 23:14:00, 深圳·龙岗区老干中心 (114.23048652799,22.717405002209), 没有肉的生活！ 深圳·龙岗区老干中心  显示地图 [组图共2张] 原图
# 2015-03-17 07:33:00, 无 (0,0), 我分享了@女生就要任性 的文章 六大食物治疗女性月经失调
# 2015-03-14 18:05:00, 无 (0,0), 月赠400分钟话费，国内电话免费呼。   http://t.cn/Rwenn7V  原图
# <|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# **用户的兴趣点**
#
# 1. **家**
#  * 地点: 深圳市龙岗区老干中心
#  * 坐标: (114.23048652799, 22.717405002209)
# 2. **工作**
#  * 地点: 深圳市龙岗区老干中心
#  * 坐标: (114.23048652799, 22.717405002209)
# 3. **学校**
#  * 无信息
# 4. **常去的地方**
#  * 无信息
# 5. **其他**
#  * 深圳市龙岗区老干中心似乎是用户的常去的地方，可能是工作或生活的地点。<|eot_id|>

# %%
import requests

def download_image(image_url, save_path):
    # 发送HTTP GET请求获取图片内容
    response = requests.get(image_url)

    # 检查请求是否成功
    if response.status_code == 200:
        # 以二进制写入方式打开本地文件
        with open(save_path, 'wb') as file:
            file.write(response.content)
        print(f"Image saved to {save_path}")
    else:
        print(f"Failed to download image. Status code: {response.status_code}")

# 示例用法
#image_url = 'https://ww1.sinaimg.cn/large/486c37b1gw6dbeejrajl1j.jpg'
save_path = 'downloaded_image.jpg'
# Out:
# Image saved to downloaded_image.jpg

# %%
image = Image.open(save_path)

messages = [
    {"role": "user", "content": [
        {"type": "image"},
        {"type": "text", "text": new_text}
    ]}
]
input_text = processor.apply_chat_template(messages, add_generation_prompt=True)
inputs = processor(
    image,
    text = input_text,
    add_special_tokens=False,
    return_tensors="pt"
).to(model.device)

output = model.generate(**inputs, max_new_tokens=256)
print(processor.decode(output[0]))
# Out:
# <|begin_of_text|><|start_header_id|>user<|end_header_id|>
#
# <|image|>The following is a record of a user posting on social media, which contains coordinate information, but the coordinates are likely to be wrong. Analyze the user's real location and what he was doing at the time based on the text content and pictures. The location should be as detailed as possible, and the coordinates must be given, including the province and city as much as possible.
#
# Contents:
# 2010-11-15 10:22:00, 无 (0,0), 刚从西藏拍的，发一张试试。  原图
# <|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# The user is likely in the city of Lhasa, Tibet, China. The image shows a monk standing on a bridge, with a large number of buildings in the background, which is consistent with the architecture of Lhasa. The coordinates provided, (0,0), are likely incorrect and should be ignored.
#
# The user was likely taking a photo of the monk and the surrounding area, possibly as part of a personal project or to share with others on social media. The time stamp suggests that the photo was taken in the morning, around 10:22 am, which is consistent with the monk's attire and the clear lighting in the image.<|eot_id|>

# %%
output_string = ""

for index, row in dfs[4].iloc[0:10].iterrows():
    output_string += f"{row['publish_time']}, {row['location']} ({row['coordinate']}), {row['content']}\n"
    #output_str = f"{row['publish_time']}, {row['location']} ({row['coordinate']}), {row['content']}"
    #print(output_str)
#print(output_string)

new_text = prompt + '\n\nContents: \n' + output_string
print(new_text)
# Out:
# Below is a record of a user's social media posts, including the date, time and geolocation of each post. Your task is to reconstruct the user's detailed trajectory throughout the specified period, inferring their likely activities and destinations beyond just the locations where they posted.
#
# Each line of your output should represent a distinct point of interest visited by the user, formatted like this:
#
# YYYY-MM-DD - AM/PM - Point of Interest (Latitude, Longitude), Type (if discernable)
#
# Example Output:
#
# 2013-10-29 - AM - 武汉·武汉科技大学 (114.26727, 30.44067), Type: School
# 2013-11-01 - PM - 民族大道 (114.397436, 30.477216), Type: Trip
# 2013-11-01 - PM - 武汉 (114.397436, 30.477216) Approximately, Type: Home
#
# Important: Do not simply list the locations of the posts. Utilize the content of the posts, time stamps, and geographical proximity to infer the user's full route and potential stops even if they didn't explicitly post from those locations.
#
# User Profile:
# 1. 居住地：
# 根据用户的帖子内容和标签，我推测用户可能居住在深圳市。他们在帖子中提到“在深圳，想学摄影的找我吧”，并且在标签中包含“深圳”的信息。
# 坐标：23.10809, 113.26467（广州，但也可能是深圳）
# 2. 工作地点：
# 用户在帖子中提到“教大家学摄影”，这表明他们可能是摄影教练或摄影师。虽然没有明确的工作地点，但根据他们的标签和帖子内容，我推测他们可能工作在深圳或附近地区。
# 坐标：23.10809, 113.26467（广州，但也可能是深圳）
# 3. 学校：
# 用户在帖子中提到“最近把课件修改了一下，做成了幻灯”，这表明他们可能是摄影教练或摄影师，并且可能在学校或培训机构工作。虽然没有明确的学校信息，但根据他们的标签和帖子内容，我推测他们可能与深圳或附近地区的学校有关。
# 坐标：23.10809, 113.26467（广州，但也可能是深圳）
# 4. 旅游目的地：
# 用户在帖子中提到“元旦去九寨沟看雪吧”，“晋陕大峡谷”，“西藏”，这表明他们喜欢旅游和摄影。根据他们的帖子内容，我推测他们可能曾经去过以下地点：
# * 九寨沟：33.33333, 103.83333
# * 晋陕大峡谷：37.91667, 109.16667
# * 西藏：29.64722, 91.11667
#
# Contents:
# 2011-01-06 14:47:00, 无 (0,0), 九寨回来了。运气依然谈很好。想雪就下了点雪，想晴，就出来了太阳。呵呵，希望今年一切如愿。
# 2010-12-15 00:03:00, 无 (0,0), 转发理由:你觉得？
# 原始用户: 時光記憶SZ
# 转发内容: 刚从西藏拍的，发一张试试。  原图
# 2010-11-15 10:22:00, 无 (0,0), 刚从西藏拍的，发一张试试。  原图
# 2010-11-15 10:19:00, 无 (0,0), 最近把课件修改了一下，做成了幻灯。教大家学摄影，更方便了。
# 2010-11-15 10:18:00, 无 (0,0), 转发理由:在深圳，想学摄影的找我吧。
# 原始用户: 時光記憶SZ
# 转发内容: 我给自己贴了 旅游、摄影、爱美女、运动、电影、教摄影 标签。
# 2010-11-15 10:17:00, 无 (0,0), 元旦去九寨沟看雪吧。
# 2010-11-15 10:19:00, 无 (0,0), 最近把课件修改了一下，做成了幻灯。教大家学摄影，更方便了。
# 2010-11-15 10:18:00, 无 (0,0), 转发理由:在深圳，想学摄影的找我吧。
# 原始用户: 時光記憶SZ
# 转发内容: 我给自己贴了 旅游、摄影、爱美女、运动、电影、教摄影 标签。
# 2010-11-15 10:17:00, 无 (0,0), 元旦去九寨沟看雪吧。
# 2011-02-16 19:26:00, 无 (0,0), 2010年，我的中国万里行记（影像游记） http://sinaurl.cn/h56pX5

# %%
messages = [
    {"role": "user", "content": [
        #{"type": "image"},
        {"type": "text", "text": new_text}
    ]}
]
input_text = processor.apply_chat_template(messages, add_generation_prompt=True)
inputs = processor(
    #image,
    text = input_text,
    add_special_tokens=False,
    return_tensors="pt"
).to(model.device)

output = model.generate(**inputs, max_new_tokens=1024)
print(processor.decode(output[0]))
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 16 Oct 2024
#
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Below is a record of a user's social media posts, including the date, time and geolocation of each post. Your task is to reconstruct the user's detailed trajectory throughout the specified period, inferring their likely activities and destinations beyond just the locations where they posted.
#
# Each line of your output should represent a distinct point of interest visited by the user, formatted like this:
#
# YYYY-MM-DD - AM/PM - Point of Interest (Latitude, Longitude), Type (if discernable)
#
# Example Output:
#
# 2013-10-29 - AM - 武汉·武汉科技大学 (114.26727, 30.44067), Type: School
# 2013-11-01 - PM - 民族大道 (114.397436, 30.477216), Type: Trip
# 2013-11-01 - PM - 武汉 (114.397436, 30.477216) Approximately, Type: Home
#
# Important: Do not simply list the locations of the posts. Utilize the content of the posts, time stamps, and geographical proximity to infer the user's full route and potential stops even if they didn't explicitly post from those locations.
#
# User Profile:
# 1. 居住地：
# 根据用户的帖子内容和标签，我推测用户可能居住在深圳市。他们在帖子中提到“在深圳，想学摄影的找我吧”，并且在标签中包含“深圳”的信息。
# 坐标：23.10809, 113.26467（广州，但也可能是深圳）
# 2. 工作地点：
# 用户在帖子中提到“教大家学摄影”，这表明他们可能是摄影教练或摄影师。虽然没有明确的工作地点，但根据他们的标签和帖子内容，我推测他们可能工作在深圳或附近地区。
# 坐标：23.10809, 113.26467（广州，但也可能是深圳）
# 3. 学校：
# 用户在帖子中提到“最近把课件修改了一下，做成了幻灯”，这表明他们可能是摄影教练或摄影师，并且可能在学校或培训机构工作。虽然没有明确的学校信息，但根据他们的标签和帖子内容，我推测他们可能与深圳或附近地区的学校有关。
# 坐标：23.10809, 113.26467（广州，但也可能是深圳）
# 4. 旅游目的地：
# 用户在帖子中提到“元旦去九寨沟看雪吧”，“晋陕大峡谷”，“西藏”，这表明他们喜欢旅游和摄影。根据他们的帖子内容，我推测他们可能曾经去过以下地点：
# * 九寨沟：33.33333, 103.83333
# * 晋陕大峡谷：37.91667, 109.16667
# * 西藏：29.64722, 91.11667
#
# Contents:
# 2011-01-06 14:47:00, 无 (0,0), 九寨回来了。运气依然谈很好。想雪就下了点雪，想晴，就出来了太阳。呵呵，希望今年一切如愿。
# 2010-12-15 00:03:00, 无 (0,0), 转发理由:你觉得？
# 原始用户: 時光記憶SZ
# 转发内容: 刚从西藏拍的，发一张试试。  原图
# 2010-11-15 10:22:00, 无 (0,0), 刚从西藏拍的，发一张试试。  原图
# 2010-11-15 10:19:00, 无 (0,0), 最近把课件修改了一下，做成了幻灯。教大家学摄影，更方便了。
# 2010-11-15 10:18:00, 无 (0,0), 转发理由:在深圳，想学摄影的找我吧。
# 原始用户: 時光記憶SZ
# 转发内容: 我给自己贴了 旅游、摄影、爱美女、运动、电影、教摄影 标签。
# 2010-11-15 10:17:00, 无 (0,0), 元旦去九寨沟看雪吧。
# 2010-11-15 10:19:00, 无 (0,0), 最近把课件修改了一下，做成了幻灯。教大家学摄影，更方便了。
# 2010-11-15 10:18:00, 无 (0,0), 转发理由:在深圳，想学摄影的找我吧。
# 原始用户: 時光記憶SZ
# 转发内容: 我给自己贴了 旅游、摄影、爱美女、运动、电影、教摄影 标签。
# 2010-11-15 10:17:00, 无 (0,0), 元旦去九寨沟看雪吧。
# 2011-02-16 19:26:00, 无 (0,0), 2010年，我的中国万里行记（影像游记） http://sinaurl.cn/h56pX5
# <|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# 根据用户的帖子内容和标签，我推测用户可能居住在深圳市。他们在帖子中提到“在深圳，想学摄影的找我吧”，并且在标签中包含“深圳”的信息。因此，我将用户的居住地设定为深圳市。
#
# 根据用户的帖子内容和标签，我推测用户可能工作在深圳市或附近地区。他们在帖子中提到“教大家学摄影”，这表明他们可能是摄影教练或摄影师。
#
# 用户在帖子中提到“最近把课件修改了一下，做成了幻灯”，这表明他们可能在学校或培训机构工作。虽然没有明确的学校信息，但根据他们的标签和帖子内容，我推测他们可能与深圳市或附近地区的学校有关。
#
# 用户在帖子中提到“元旦去九寨沟看雪吧”，“晋陕大峡谷”，“西藏”，这表明他们喜欢旅游和摄影。根据他们的帖子内容，我推测他们可能曾经去过以下地点：
#
# * 九寨沟：33.33333, 103.83333
# * 晋陕大峡谷：37.91667, 109.16667
# * 西藏：29.64722, 91.11667
#
# 基于这些信息，我尝试重建用户的详细行程如下：
#
# 2010-11-15 - AM - 深圳 (23.10809, 113.26467), Type: Home
# 2010-11-15 - AM - 深圳 (23.10809, 113.26467), Type: Work
# 2010-11-15 - AM - 学校 (23.10809, 113.26467), Type: School
# 2010-11-15 - PM - 深圳 (23.10809, 113.26467), Type: Home
# 2010-12-15 - PM - 西藏 (29.64722, 91.11667), Type: Tourism
# 2010-12-15 - PM - 九寨沟 (33.33333, 103.83333), Type: Tourism
# 2010-12-15 - PM - 晋陕大峡谷 (37.91667, 109.16667), Type: Tourism
# 2011-01-06 - AM - 九寨沟 (33.33333, 103.83333), Type: Tourism
# 2011-02-16 - PM - 深圳 (23.10809, 113.26467), Type: Home
#
# 请注意，这是我的推测结果，可能存在一定的不确定性。<|eot_id|>

# %%
messages = [
    {"role": "user", "content": [
        #{"type": "image"},
        {"type": "text", "text": new_text}
    ]}
]
input_text = processor.apply_chat_template(messages, add_generation_prompt=True)
inputs = processor(
    #image,
    text = input_text,
    add_special_tokens=False,
    return_tensors="pt"
).to(model.device)

output = model.generate(**inputs, max_new_tokens=1024)
print(processor.decode(output[0]))
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 16 Oct 2024
#
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Below is a record of a user's social media posts, including the date, time and geolocation of each post. Your task is to reconstruct the user's detailed trajectory throughout the specified period, inferring their likely activities and destinations beyond just the locations where they posted.
#
# Each line of your output should represent a distinct point of interest visited by the user, formatted like this:
#
# YYYY-MM-DD - AM/PM - Point of Interest (Latitude, Longitude), Type (if discernable)
#
# Example Output:
#
# 2013-10-29 - AM - 武汉·武汉科技大学 (114.26727, 30.44067), Type: School
# 2013-11-01 - PM - 民族大道 (114.397436, 30.477216), Type: Trip
# 2013-11-01 - PM - 武汉 (114.397436, 30.477216) Approximately, Type: Home
#
# Important: Do not simply list the locations of the posts. Utilize the content of the posts, time stamps, and geographical proximity to infer the user's full route and potential stops even if they didn't explicitly post from those locations.
#
# User Profile:
# 1. 用户的家乡或家庭地址：
# - 用户可能生活在武汉市，具体地址为民族大道（114.396344, 30.477156）。
#
# 2. 用户的工作或学校：
# - 用户可能是武汉科技大学的学生，具体地址为武汉科技大学（114.26727, 30.44067）。
#
# 3. 用户的常去地：
# - 用户可能经常去软件园中路（114.40347, 30.481615）。
# - 用户可能经常去白沙洲大道（114.259519, 30.440047）。
# - 用户可能经常去知行路（114.263999, 30.436998）。
# - 用户可能经常去民族大道（114.396422, 30.477919）。
# - 用户可能经常去软件园一路（114.400347, 30.473845）。
#
#
# Contents:
# 2013-11-30 00:00:00, 民族大道 (114.396422,30.477919), 今日之突发事件，我爸坐车来武汉打工！这怎么可以！还好我行动果断，用我的霸道在付家坡把我爸拦截了然后又给送了回去，我爸已经平安到家我很高兴，我爱我的家人[呵呵]，我会用我的全部去爱他们保护他们❤！@呵呵，u my fml❤ 我在:民族大道  显示地图
# 2013-11-27 22:11:00, 无 (0,0), 使用有道云笔记，轻松同步、管理您各终端的所有笔记。三重备份，存储数据安全有保障。免费的超大存储空间，无限量增长。激活后即可免费获得2GB云存储空间。赶紧来体验吧。 网页链接   原图
# 2013-11-27 12:55:00, 无 (0,0), 初步验证，就我这乒乓球水平都能把他们轻轻松松11：2，11：3，哎，国乒啊，，，
# 2013-11-24 23:16:00, 民族大道 (114.39644,30.477713), 看《老有所依》看得好有感觉，，，明天又要上班了，啊，早睡～ 我在:民族大道  显示地图
# 2013-12-27 15:14:00, 南湖大道 (114.401842,30.480903), 要是上班没有规定时间规定质量的任务，那我就可以长期来厕所磨蹭，此曰“划水”，，， 我在:南湖大道  显示地图
# 2013-12-27 00:33:00, 软件园三路 (114.401268,30.474922), 不愿睡觉，睡觉很无聊[睡觉][睡觉][睡觉] 我在:软件园三路  显示地图 原图
# 2013-12-24 23:33:00, 无 (0,0), 转发理由:若得苍姐送的皮肤，我愿意去打职业，，，
# 原始用户: 小苍cany
# 转发内容: 朋友们，大家平安夜快乐^_^，希望大家开开心心，平平安安，今天你吃苹果了吗？你们的平安夜如何度过的？……（因为元旦有旅游计划，所以我在努力的赶制视频，保证如期的更新）。好了，来点实际的小福利。转播此微博我会在明天抽取一位朋友获得小苍特别BUFF之：LOL皮肤任意选一个小苍赠送。明天公布。  原图
# 2013-12-18 23:33:00, 无 (0,0), 转发微博已被删除
# 2013-12-18 14:21:00, 无 (0,0), 转发理由:有道云，不错不错、、、
# 原始用户: 有道云笔记收藏
# 转发内容: 小伙伴们快快用起来！即日起至2014年1月30日，每周都会在小伙伴中产生一名幸运儿，获得神秘奖品！怎样做才能获奖呢？参加办法很简单，只需多多使用@有道云笔记收藏 就可以啦！剩下的就交给运气喽~每周都会有一名幸运儿呢！还不快快行动  原图
# 2013-12-16 21:21:00, 无 (0,0), 我的床花不花？？？囍  原图
# <|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# 根据用户的微博内容和地理位置信息，以下是用户的详细轨迹：
#
# 2013-11-30 - PM - 民族大道 (114.396344, 30.477156), Type: Home
# 2013-11-30 - AM - 民族大道 (114.396422, 30.477919), Type: Home
# 2013-11-27 - PM - 武汉科技大学 (114.26727, 30.44067), Type: School
# 2013-11-27 - AM - 软件园中路 (114.40347, 30.481615), Type: Work or Study
# 2013-11-24 - PM - 武汉科技大学 (114.26727, 30.44067), Type: School
# 2013-11-24 - AM - 民族大道 (114.39644, 30.477713), Type: Home
# 2013-12-27 - PM - 软件园三路 (114.401268, 30.474922), Type: Relaxation
# 2013-12-27 - AM - 南湖大道 (114.401842, 30.480903), Type: Work
# 2013-12-24 - PM - 软件园三路 (114.401268, 30.474922), Type: Relaxation
# 2013-12-18 - PM - 知行路 (114.263999, 30.436998), Type: Work or Study
# 2013-12-18 - AM - 软件园一路 (114.400347, 30.473845), Type: Work or Study
# 2013-12-16 - PM - 白沙洲大道 (114.259519, 30.440047), Type: Relaxation
#
# 注意：用户的轨迹可能有所不同，因为一些位置信息可能不准确或不完整。<|eot_id|>

# %%
messages = [
    {"role": "user", "content": [
        #{"type": "image"},
        {"type": "text", "text": new_text}
    ]}
]
input_text = processor.apply_chat_template(messages, add_generation_prompt=True)
inputs = processor(
    #image,
    text = input_text,
    add_special_tokens=False,
    return_tensors="pt"
).to(model.device)

output = model.generate(**inputs, max_new_tokens=512)
print(processor.decode(output[0]))
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 16 Oct 2024
#
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Below is a record of a user's social media posts, including the date, time and geolocation of each post. Your task is to reconstruct the user's detailed trajectory throughout the specified period, inferring their likely activities and destinations beyond just the locations where they posted.
#
# Each line of your output should represent a distinct point of interest visited by the user, formatted like this:
#
# YYYY-MM-DD - AM/PM - Point of Interest (Latitude, Longitude), Type (if discernable)
#
# Example Output:
#
# 2013-10-29 - AM - 武汉·武汉科技大学 (114.26727, 30.44067), Type: School
# 2013-11-01 - PM - 民族大道 (114.397436, 30.477216), Type: Trip
# 2013-11-01 - PM - 武汉 (114.397436, 30.477216) Approximately, Type: Home
#
# Important: Do not simply list the locations of the posts. Utilize the content of the posts, time stamps, and geographical proximity to infer the user's full route and potential stops even if they didn't explicitly post from those locations.
#
# Contents:
# 2013-07-27 21:47:00, 无 (0,0), 突然发现，亲情，友情，爱情，在金钱面前变的不堪一击。
# 2013-07-23 18:58:00, 无 (0,0), 一个月快完了，还不开单，天天上通班，好累
# 2013-07-18 01:30:00, 无 (0,0), 又是很晚才休息，这几天都是这样，快受不了。
# 2013-06-18 06:45:00, 无 (0,0), 转发微博已被删除
# 2013-06-18 06:37:00, 无 (0,0), 今天起得太早，好困，但是想到回家就不困了，久违的家人很快就要见到你们。很开心，爸妈女儿回来了
# 2013-10-01 23:20:00, 南新路 (113.918617,22.534954), 新的一月，新的一天，新的开始，第一天就开单赚钱，继续开单，好运连连 我在:南新路  显示地图
# 2013-10-01 09:37:00, 桃园路 (113.918319,22.532962), 大家国庆快乐 我在:桃园路  显示地图
# 2013-09-30 10:38:00, 前海路 (113.913757,22.535783), #你好明天# 我们明天的明天还是上班，唉，可怜的孩子 我在:前海路  显示地图
# 2013-09-29 12:13:00, 无 (0,0), 转发理由:说的不错
# 原始用户: 加措上师-慈爱基金
# 转发内容: 坚定的信念是获取成功的动力。在困难面前，如果我们能在众人都放弃时再多坚持一秒，那么，最后的胜利一定是属于我们的。很多时候，成功都是在最后一刻才蹒跚到来。因此，做任何事情，我们都不应该半途而废，哪怕前行的道路再苦再难，也要坚持下去，这样才不会在自己的人生路上留下太多的遗憾。  原图
# 2013-09-17 14:56:00, 无 (0,0), 还好，老爸没事了，放心了。
# <|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# 基于提供的用户社交媒体记录，我尝试重构用户的详细轨迹。以下是我的结果：
#
# 2013-07-18 - PM - 无 (0,0), Type: Rest
# 2013-07-23 - PM - 无 (0,0), Type: Work
# 2013-07-27 - PM - 无 (0,0), Type: Reflection
# 2013-06-18 - AM - 无 (0,0), Type: Travel (回家)
# 2013-06-18 - AM - 无 (0,0), Type: Home
# 2013-09-17 - PM - 无 (0,0), Type: Visit Family
# 2013-09-30 - AM - 前海路 (113.913757,22.535783), Type: Work
# 2013-09-30 - PM - 前海路 (113.913757,22.535783), Type: Home
# 2013-10-01 - AM - 桃园路 (113.918319,22.532962), Type: Work
# 2013-10-01 - PM - 南新路 (113.918617,22.534954), Type: Work
#
# 我根据以下信息进行推断：
#
# 1. 用户于 2013 年 6 月 18 日早上从某个未知地点出发，前往家里（Type: Travel），并在当天早上到达家里（Type: Home）。
# 2. 用户于 2013 年 9 月 17 日下午访问了他们的家人（Type: Visit Family）。
# 3. 用户于 2013 年 9 月 30 日上午和下午在前海路工作（Type: Work），并在当天晚上返回前海路（Type: Home）。
# 4. 用户于 2013 年 10 月 1 日上午和下午在桃园路和南新路工作（Type: Work）。
#
# 我还根据用户的社交媒体记录推断了他们的日常活动和情绪状态：
#
# 1. 用户似乎经常工作长时间，经常在晚上才休息（2013 年 7 月 18 日，2013 年 7 月 23 日）。
# 2. 用户似乎很关心家人，特别是在 2013 年 9 月 17 日访问家人的时候。
# 3. 用户似乎很感性，

# %%
messages = [
    {"role": "user", "content": [
        #{"type": "image"},
        {"type": "text", "text": new_text}
    ]}
]
input_text = processor.apply_chat_template(messages, add_generation_prompt=True)
inputs = processor(
    #image,
    text = input_text,
    add_special_tokens=False,
    return_tensors="pt"
).to(model.device)

output = model.generate(**inputs, max_new_tokens=512)
print(processor.decode(output[0]))
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 16 Oct 2024
#
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#
# The following is a record of posts published by users on social media, including the date, time, geographic location, and latitude and longitude coordinates of each post. Your task is to find the user's points of interest, including but not limited to the location of the user's home, workplace, school, places they often go to, and the coordinate types of these places. The location should be as detailed as possible, the coordinates must be given, and the province and city should be included as much as possible.
#
# Example Output:
# The user likely lives in 广州 (23.10809, 113.26467).
# The user likely to be a student at 武汉科技大学 (114.26727, 30.44067).
# The user traveled to 九寨沟 (33.33333, 103.83333) to take photos, as mentioned in the post from 2010-11-15.
#
# Contents:
# 2011-01-06 14:47:00, 无 (0,0), 九寨回来了。运气依然谈很好。想雪就下了点雪，想晴，就出来了太阳。呵呵，希望今年一切如愿。
# 原始用户: 時光記憶SZ
# 转发内容: 西藏  原图
# 2011-03-19 15:15:00, 无 (0,0), @快乐拼客 的微群 "背包摄影族" 挺不错的 网页链接 推荐大家也来看看~  原图
# 2011-03-19 15:15:00, 无 (0,0), 新群开张，欢迎喜欢摄影、旅游、交流的各种朋友，尤其是深圳的朋友，一起来这里聚聚。
# 2011-03-19 15:00:00, 无 (0,0), 西藏  原图
# 2011-03-18 01:27:00, 无 (0,0), 分享图片  原图
# 2011-03-19 16:18:00, 无 (0,0), 新群开张，没事多来坐坐哦。呵呵  原图
# 2011-03-19 15:21:00, 无 (0,0), 转发理由:谢谢哦，这是去年西藏拍的。我成立了“背包摄影族”群，欢迎加入哦
# 原始用户: 時光記憶SZ
# 转发内容: 西藏  原图
# 2011-03-19 15:15:00, 无 (0,0), @快乐拼客 的微群 "背包摄影族" 挺不错的 网页链接 推荐大家也来看看~  原图
# <|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# 根据提供的数据，我尝试分析用户的活动轨迹，推断出他们的兴趣点和可能的居住地、工作地点、学校等。
#
# 1. 居住地：
# 根据用户的帖子内容和标签，我推测用户可能居住在深圳市。他们在帖子中提到“在深圳，想学摄影的找我吧”，并且在标签中包含“深圳”的信息。
#
# 坐标：23.10809, 113.26467（广州，但也可能是深圳）
#
# 2. 工作地点：
# 用户在帖子中提到“教大家学摄影”，这表明他们可能是摄影教练或摄影师。虽然没有明确的工作地点，但根据他们的标签和帖子内容，我推测他们可能工作在深圳或附近地区。
#
# 坐标：23.10809, 113.26467（广州，但也可能是深圳）
#
# 3. 学校：
# 用户在帖子中提到“最近把课件修改了一下，做成了幻灯”，这表明他们可能是摄影教练或摄影师，并且可能在学校或培训机构工作。虽然没有明确的学校信息，但根据他们的标签和帖子内容，我推测他们可能与深圳或附近地区的学校有关。
#
# 坐标：23.10809, 113.26467（广州，但也可能是深圳）
#
# 4. 旅游目的地：
# 用户在帖子中提到“元旦去九寨沟看雪吧”，“晋陕大峡谷”，“西藏”，这表明他们喜欢旅游和摄影。根据他们的帖子内容，我推测他们可能曾经去过以下地点：
#
# * 九寨沟：33.33333, 103.83333
# * 晋陕大峡谷：37.91667, 109.16667
# * 西藏：29.64722, 91.11667
#
# 5. 其他兴趣点：
# 用户在帖子中提到“运动”、“电影”、“爱美女”等，这表明他们可能有多个兴趣点。虽然没有明确的坐标信息，但根据他们的标签和帖子内容，我推测他们可能喜欢以下地点：
#
# * 体育场或运动场：23.10809, 113.26467

# %%
output = model.generate(**inputs, max_new_tokens=512)
print(processor.decode(output[0]))
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 15 Oct 2024
#
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Below is a record of a user's social media posts, including the date, time and geolocation of each post. Your task is to reconstruct the user's detailed trajectory throughout the specified period, inferring their likely activities and destinations beyond just the locations where they posted.
#
# Each line of your output should represent a distinct point of interest visited by the user, formatted like this:
#
# YYYY-MM-DD - AM/PM - Point of Interest (Latitude, Longitude), Type (if discernable)
#
# Example Output:
#
# 2013-10-29 - AM - 武汉·武汉科技大学 (114.26727, 30.44067), Type: School
# 2013-11-01 - PM - 民族大道 (114.397436, 30.477216), Type: Trip
# 2013-11-01 - PM - (114.397436, 30.477216)Approximately, Type: Home
#
# Important: Do not simply list the locations of the posts. Utilize the content of the posts, time stamps, and geographical proximity to infer the user's full route and potential stops even if they didn't explicitly post from those locations.
#
# Contents:
# 2011-01-06 14:47:00, 无 (0,0), 九寨回来了。运气依然谈很好。想雪就下了点雪，想晴，就出来了太阳。呵呵，希望今年一切如愿。
# 2010-12-15 00:03:00, 无 (0,0), 转发理由:你觉得？
# 原始用户: 時光記憶SZ
# 转发内容: 刚从西藏拍的，发一张试试。  原图
# 2010-11-15 10:22:00, 无 (0,0), 刚从西藏拍的，发一张试试。  原图
# 2010-11-15 10:19:00, 无 (0,0), 最近把课件修改了一下，做成了幻灯。教大家学摄影，更方便了。
# 2010-11-15 10:18:00, 无 (0,0), 转发理由:在深圳，想学摄影的找我吧。
# 原始用户: 時光記憶SZ
# 转发内容: 我给自己贴了 旅游、摄影、爱美女、运动、电影、教摄影 标签。
# 2010-11-15 10:17:00, 无 (0,0), 元旦去九寨沟看雪吧。
# 2010-11-15 10:19:00, 无 (0,0), 最近把课件修改了一下，做成了幻灯。教大家学摄影，更方便了。
# 2010-11-15 10:18:00, 无 (0,0), 转发理由:在深圳，想学摄影的找我吧。
# 原始用户: 時光記憶SZ
# 转发内容: 我给自己贴了 旅游、摄影、爱美女、运动、电影、教摄影 标签。
# 2010-11-15 10:17:00, 无 (0,0), 元旦去九寨沟看雪吧。
# 2011-02-16 19:26:00, 无 (0,0), 2010年，我的中国万里行记（影像游记） http://sinaurl.cn/h56pX5
# <|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# Based on the provided social media posts, I will attempt to reconstruct the user's trajectory throughout the specified period. Here's the inferred route:
#
# 2010-11-15 - AM - 深圳 (23.10809, 113.26467), Type: Home
# 2010-11-15 - AM - (23.10809, 113.26467)Approximately, Type: Home
# 2010-11-15 - AM - 九寨沟 (33.33333, 103.83333), Type: Trip
# 2010-11-15 - AM - (33.33333, 103.83333)Approximately, Type: Trip
# 2010-12-15 - AM - (0, 0)Approximately, Type: Unknown
# 2011-01-06 - AM - (0, 0)Approximately, Type: Unknown
# 2011-02-16 - AM - (0, 0)Approximately, Type: Unknown
# 2011-02-16 - PM - (0, 0)Approximately, Type: Unknown
#
# Inferred Route:
#
# * The user likely lives in 深圳 (23.10809, 113.26467) based on the post from 2010-11-15, where they mention teaching photography in深圳.
# * The user then traveled to 九寨沟 (33.33333, 103.83333) to take photos, as mentioned in the post from 2010-11-15.
# * The posts from 2010-12-15, 2011-01-06, and 2011-02-16 seem to be from unknown locations, possibly while the user was traveling or on a trip.
# * The post from 2011-02-16 mentions the user's "中国万里行记" (China's Long March), which suggests that the user may have been traveling extensively throughout China.
#
# Note: The inferred route is based on the content of the posts, time stamps, and geographical proximity. However, some assumptions and inferences have been made to reconstruct the user's trajectory.<|eot_id|>
